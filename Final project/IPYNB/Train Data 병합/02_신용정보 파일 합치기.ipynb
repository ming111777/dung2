# %%
# 기본 라이브러리
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 경고 뜨지 않게
import warnings
warnings.filterwarnings('ignore')

# %%
# 6개 parquet 파일 경로 리스트 
file_list = [
    'open/train/2.신용정보/201807_train_신용정보.parquet',
    'open/train/2.신용정보/201808_train_신용정보.parquet',
    'open/train/2.신용정보/201809_train_신용정보.parquet',
    'open/train/2.신용정보/201810_train_신용정보.parquet',
    'open/train/2.신용정보/201811_train_신용정보.parquet',
    'open/train/2.신용정보/201812_train_신용정보.parquet'
]

# 빈 데이터프레임 리스트 생성
dfs = []

# 각 파일을 읽어서 dfs 리스트에 추가
for file in file_list:
    df = pd.read_parquet(file)
    dfs.append(df)

# 데이터프레임 합치기 (행 기준으로 아래로 붙이기)
merged_df = pd.concat(dfs, ignore_index=True)

# %%
# 합친 데이터 확인
print(merged_df.shape)
print(merged_df.head())
# Out:
# (2400000, 42)
#      기준년월            ID  최초한도금액  카드이용한도금액  CA한도금액  일시상환론한도금액  월상환론한도금액  \
# 0  201807  TRAIN_000000       0     19354    7270          0         0
# 1  201807  TRAIN_000001       0      9996    5718      41996     90611
# 2  201807  TRAIN_000002       0     88193   35207          0         0
# 3  201807  TRAIN_000003       0     19062    6531          0         0
# 4  201807  TRAIN_000004       0    177222   47149      48000    155020
#
#    CA이자율_할인전  CL이자율_할인전  RV일시불이자율_할인전  ...  연체감액여부_R3M  한도심사요청건수  한도요청거절건수  \
# 0  22.995207  18.254978     17.264967  ...           0        0회         0
# 1  14.793821  14.834873     10.622446  ...           0        0회         0
# 2  22.014276  17.875321     17.155829  ...           0        0회         0
# 3  22.998014  22.999453     19.293674  ...           0        0회         0
# 4  14.661948  10.897410     10.654587  ...           0        0회         0
#
#    한도심사요청후경과월 한도심사거절후경과월  시장단기연체여부_R6M  시장단기연체여부_R3M  시장연체상환여부_R6M  \
# ...

# %%
# 필요하면 하나로 합친 데이터 저장
merged_df.to_parquet('open/train/2.신용정보/2018_train_신용정보.parquet')

# %%
df = pd.read_parquet ('open/train/2.신용정보/2018_train_신용정보.parquet')
df
# Out:
#            기준년월            ID  최초한도금액  카드이용한도금액  CA한도금액  일시상환론한도금액  월상환론한도금액  \
# 0        201807  TRAIN_000000       0     19354    7270          0         0
# 1        201807  TRAIN_000001       0      9996    5718      41996     90611
# 2        201807  TRAIN_000002       0     88193   35207          0         0
# 3        201807  TRAIN_000003       0     19062    6531          0         0
# 4        201807  TRAIN_000004       0    177222   47149      48000    155020
# ...         ...           ...     ...       ...     ...        ...       ...
# 2399995  201812  TRAIN_399995       0     20070   10167          0     54445
# 2399996  201812  TRAIN_399996       0     84217   31159          0    156800
# 2399997  201812  TRAIN_399997       0     52612   19429          0         0
# 2399998  201812  TRAIN_399998       0     10002    4228      90004    180906
# 2399999  201812  TRAIN_399999       0     86094   25133          0         0
#
# ...
