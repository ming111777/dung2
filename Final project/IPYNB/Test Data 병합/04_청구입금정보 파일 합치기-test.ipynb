# %%
# 기본 라이브러리
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 경고 뜨지 않게
import warnings
warnings.filterwarnings('ignore')

# %%
# 6개 parquet 파일 경로 리스트 
file_list = [
    'open/test/4.청구입금정보/201807_test_청구정보.parquet',
    'open/test/4.청구입금정보/201808_test_청구정보.parquet',
    'open/test/4.청구입금정보/201809_test_청구정보.parquet',
    'open/test/4.청구입금정보/201810_test_청구정보.parquet',
    'open/test/4.청구입금정보/201811_test_청구정보.parquet',
    'open/test/4.청구입금정보/201812_test_청구정보.parquet',

]

# 빈 데이터프레임 리스트 생성
dfs = []

# 각 파일을 읽어서 dfs 리스트에 추가
for file in file_list:
    df = pd.read_parquet(file)
    dfs.append(df)

# 데이터프레임 합치기 (행 기준으로 아래로 붙이기)
merged_df = pd.concat(dfs, ignore_index=True)

# %%
# 합친 데이터 확인
print(merged_df.shape)
print(merged_df.head())
# Out:
# (600000, 46)
#      기준년월          ID  대표결제일 대표결제방법코드 대표청구지고객주소구분코드 대표청구서수령지구분코드 청구서수령방법  \
# 0  201807  TEST_00000     25     자동이체           미확인          이메일     이메일
# 1  201807  TEST_00001     13     자동이체           미확인    당사페이앱+이메일   문자메세지
# 2  201807  TEST_00002     25     자동이체           미확인          이메일     이메일
# 3  201807  TEST_00003     25     자동이체           주거지           우편      우편
# 4  201807  TEST_00004     27     자동이체           주거지           우편      우편
#
#    청구서발송여부_B0  청구서발송여부_R3M  청구서발송여부_R6M  ...  할인금액_청구서_B0M  상환개월수_결제일_R6M  \
# 0           1            1            1  ...             0              5
# 1           1            1            1  ...            14              6
# 2           1            1            1  ...            50              6
# 3           1            1            1  ...             0              2
# 4           1            1            1  ...             0              6
#
# ...

# %%
# 필요하면 하나로 합친 데이터 저장
merged_df.to_parquet('open/test/4.청구입금정보/2018_test_청구입금정보.parquet')

# %%
df = pd.read_parquet ('open/test/4.청구입금정보/2018_test_청구입금정보.parquet')
df
# Out:
#           기준년월          ID  대표결제일 대표결제방법코드 대표청구지고객주소구분코드 대표청구서수령지구분코드 청구서수령방법  \
# 0       201807  TEST_00000     25     자동이체           미확인          이메일     이메일
# 1       201807  TEST_00001     13     자동이체           미확인    당사페이앱+이메일   문자메세지
# 2       201807  TEST_00002     25     자동이체           미확인          이메일     이메일
# 3       201807  TEST_00003     25     자동이체           주거지           우편      우편
# 4       201807  TEST_00004     27     자동이체           주거지           우편      우편
# ...        ...         ...    ...      ...           ...          ...     ...
# 599995  201812  TEST_99995     20     자동이체            회사           우편      우편
# 599996  201812  TEST_99996     20     자동이체           주거지           우편      우편
# 599997  201812  TEST_99997     15     자동이체           미확인          이메일     이메일
# 599998  201812  TEST_99998     12     자동이체           미확인    K톡명세서+이메일      K톡
# 599999  201812  TEST_99999      5     자동이체           주거지           우편      우편
#
# ...
