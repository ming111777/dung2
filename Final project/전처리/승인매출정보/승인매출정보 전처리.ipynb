# %%
# 기본 라이브러리 임포트
import pandas as pd             
import numpy as np             
import matplotlib.pyplot as plt 
import seaborn as sns           
import gc                       # 가비지 컬렉션(메모리 해제)
import re                       # 정규 표현식 처리
from collections import defaultdict  # 기본값이 있는 딕셔너리 생성

# 경고 메시지 억제
import warnings
warnings.filterwarnings('ignore')   

# 그래프 스타일 설정
sns.set()                           # seaborn 기본 스타일 적용

# matplotlib 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # 한글 폰트 설정
# plt.rcParams['font.family'] = 'AppleGothic'  
plt.rcParams['figure.figsize'] = (12, 6)       # 그림 크기 설정 (가로, 세로)
plt.rcParams['font.size'] = 14                 # 폰트 크기 설정
plt.rcParams['axes.unicode_minus'] = False     # 마이너스 기호 깨짐 방지

# 결측치 시각화 라이브러리 임포트
import missingno                          # 결측치 분포를 시각화하는 유틸리티

# 범주형 변수 레이블 인코딩을 위한 도구 임포트
from sklearn.preprocessing import LabelEncoder

# 중복 조합 생성에 사용할 product 함수 임포트
from itertools import product

# 회귀 및 통계 분석을 위한 statsmodels 임포트
import statsmodels.api as sm

# %% [markdown]
# ### 데이터 병합

# %%
# 채널정보 파일 읽기
channel_df = pd.read_parquet('open/concat/2018_승인매출정보.parquet')

# 회원정보 파일 읽기
member_df  = pd.read_parquet('open/concat/2018_회원정보.parquet')

# 회원정보에서 ID와 Segment 컬럼만 추출
member_seg = member_df[['ID', 'Segment']]

# 중복된 ID 개수 확인
dup_count = member_seg['ID'].duplicated().sum()
print(f'중복된 ID 개수: {dup_count}')

# 중복된 ID를 첫 번째 항목만 남기고 제거
member_seg_unique = member_seg.drop_duplicates(subset='ID', keep='first')
print(f'중복 제거 후 행 수: {len(member_seg_unique)}')

# 채널정보에 Segment 컬럼 병합 (1:1 조인 보장)
df = channel_df.merge(member_seg_unique, on='ID', how='left')

# 결과 확인
print("병합 후 데이터프레임 크기:", df.shape)
print(df.head())

# 병합된 파일 저장
df.to_parquet('2018_승인매출정보_with_segment.parquet', index=False)
# Out:
# 중복된 ID 개수: 2500000
# 중복 제거 후 행 수: 500000
# 병합 후 데이터프레임 크기: (3000000, 407)
#      기준년월            ID  최종이용일자_기본  최종이용일자_신판  최종이용일자_CA  최종이용일자_카드론  \
# 0  201807  TRAIN_000000   20180719   20180713   20180719       10101
# 1  201807  TRAIN_000001   20180719   20180719   20170728    20170327
# 2  201807  TRAIN_000002   20180706   20180706   20180706    20151119
# 3  201807  TRAIN_000003   20180721   20180715   20180721       10101
# 4  201807  TRAIN_000004   20180124   20180124      10101       10101
#
#    최종이용일자_체크  최종이용일자_일시불  최종이용일자_할부  이용건수_신용_B0M  ...  승인거절건수_BL_B0M  \
# 0   20180203    20180709   20180713           11  ...              0
# 1      10101    20180719   20171231           13  ...              0
# 2   20141230    20180706   20180627           12  ...              0
# 3   20141111    20180704   20180715            6  ...              0
# 4   20180512    20180124      10101           -2  ...              0
#
#    승인거절건수_입력오류_B0M  승인거절건수_기타_B0M  승인거절건수_R3M  승인거절건수_한도초과_R3M  승인거절건수_BL_R3M  \
# 0                0              0           3                3              0
# 1                0              0           3                3              0
# 2                0              0           0                0              0
# 3                0              0           3                3              0
# 4                0              0           0                0              0
#
#    승인거절건수_입력오류_R3M  승인거절건수_기타_R3M      이용금액대  Segment
# 0                0              0  01.100만원+        D
# 1                0              0   03.30만원+        E
# 2                0              0  01.100만원+        C
# 3                0              0  01.100만원+        D
# 4                0              0     09.미사용        E
#
# [5 rows x 407 columns]

# %%
# 데이터를 불러온다.
df = pd.read_parquet('2018_승인매출정보_with_segment.parquet')

# %% [markdown]
# ### 값이 하나 뿐인 컬럼과 값이 모두 0인 컬럼도 제외

# %%
# 전부 0인 컬럼 찾기
zero_cols = [c for c in df.columns if df[c].eq(0).all()]

print("모두 0인 컬럼 (제거 대상):")
print(zero_cols)

# 전부 0인 컬럼 제거
df.drop(columns=zero_cols, inplace = True)

# 4) 결과 확인
print("최종 DataFrame shape:", df.shape)
# Out:
# 모두 0인 컬럼 (제거 대상):
# ['이용건수_부분무이자_B0M', '이용금액_부분무이자_B0M', '여유_여행이용금액', '납부_렌탈료이용금액', '납부_유선방송이용금액', '납부_건강연금이용금액', '할부건수_부분_3M_R12M', '할부건수_부분_6M_R12M', '할부건수_부분_14M_R12M', '할부금액_부분_3M_R12M', 'RP건수_유선방송_B0M', 'RP건수_건강_B0M', '증감_RP건수_유선방송_전월', '증감_RP건수_건강_전월', '이용개월수_당사페이_R6M', '이용금액_당사페이_R6M', '이용금액_당사기타_R6M', '이용건수_당사페이_R6M', '이용건수_당사기타_R6M', '이용금액_당사페이_R3M', '이용금액_당사기타_R3M', '이용건수_당사페이_R3M', '이용건수_당사기타_R3M', '이용금액_당사페이_B0M', '이용금액_당사기타_B0M', '이용건수_당사페이_B0M', '이용건수_당사기타_B0M', '승인거절건수_입력오류_B0M', '승인거절건수_기타_B0M']
# 최종 DataFrame shape: (3000000, 378)

# %%
# 추출: 모든 값이 동일한(상수) 컬럼 찾기
const_cols = [c for c in df.columns if df[c].nunique(dropna=False) == 1]

# 계산: 제거 대상 컬럼 목록 출력
print("모두 같은 값인 컬럼 (제거 대상):")
print(const_cols)

# 생성: 상수 컬럼 제거
df.drop(columns=const_cols, inplace=True)

# 확인: 최종 DataFrame 상태 출력
print("최종 DataFrame shape:", df.shape)
# Out:
# 모두 같은 값인 컬럼 (제거 대상):
# ['RP후경과월_유선방송', 'RP후경과월_건강']
# 최종 DataFrame shape: (3000000, 376)

# %%
# 전체 컬럼 리스트 생성
cols = df.columns.tolist()

# 최빈값 비율이 99.9% 초과하는 컬럼 수집
low_variance_cols = []
for col in cols:
    # 컬럼별 최빈값 비율 확인
    top_ratio = df[col].value_counts(normalize=True, dropna=False).iloc[0]
    if top_ratio > 0.999:
        low_variance_cols.append(col)

# 제거 대상 컬럼 목록 출력
print("제거 대상 컬럼:", low_variance_cols)

# 제거 대상 컬럼 삭제
df.drop(columns=low_variance_cols, inplace=True)

# 최종 컬럼 리스트 출력
print("최종 컬럼 리스트:", df.columns.tolist())
# Out:
# 제거 대상 컬럼: ['이용건수_카드론_B0M', '이용금액_카드론_B0M', '이용건수_부분무이자_R12M', '이용건수_부분무이자_R3M', '이용개월수_부분무이자_R3M', '교통_통행료이용금액', '할부건수_14M_R12M', '할부건수_유이자_14M_R12M', '할부건수_무이자_14M_R12M', '할부건수_부분_12M_R12M', '할부금액_부분_6M_R12M', '할부금액_부분_14M_R12M', 'RP건수_학습비_B0M', '증감_RP건수_아파트_전월', '증감_RP건수_제휴사서비스직접판매_전월', '증감_RP건수_학습비_전월', '신청건수_ATM_CL_B0', '신청건수_ATM_CL_R6M', '승인거절건수_BL_B0M', '승인거절건수_입력오류_R3M']
# 최종 컬럼 리스트: ['기준년월', 'ID', '최종이용일자_기본', '최종이용일자_신판', '최종이용일자_CA', '최종이용일자_카드론', '최종이용일자_체크', '최종이용일자_일시불', '최종이용일자_할부', '이용건수_신용_B0M', '이용건수_신판_B0M', '이용건수_일시불_B0M', '이용건수_할부_B0M', '이용건수_할부_유이자_B0M', '이용건수_할부_무이자_B0M', '이용건수_CA_B0M', '이용건수_체크_B0M', '이용금액_일시불_B0M', '이용금액_할부_B0M', '이용금액_할부_유이자_B0M', '이용금액_할부_무이자_B0M', '이용금액_CA_B0M', '이용금액_체크_B0M', '이용후경과월_신용', '이용후경과월_신판', '이용후경과월_일시불', '이용후경과월_할부', '이용후경과월_할부_유이자', '이용후경과월_할부_무이자', '이용후경과월_부분무이자', '이용후경과월_CA', '이용후경과월_체크', '이용후경과월_카드론', '이용건수_신용_R12M', '이용건수_신판_R12M', '이용건수_일시불_R12M', '이용건수_할부_R12M', '이용건수_할부_유이자_R12M', '이용건수_할부_무이자_R12M', '이용건수_CA_R12M', '이용건수_체크_R12M', '이용건수_카드론_R12M', '이용금액_일시불_R12M', '이용금액_할부_R12M', '이용금액_할부_유이자_R12M', '이용금액_할부_무이자_R12M', '이용금액_부분무이자_R12M', '이용금액_CA_R12M', '이용금액_체크_R12M', '이용금액_카드론_R12M', '최대이용금액_일시불_R12M', '최대이용금액_할부_R12M', '최대이용금액_할부_유이자_R12M', '최대이용금액_할부_무이자_R12M', '최대이용금액_부분무이자_R12M', '최대이용금액_CA_R12M', '최대이용금액_체크_R12M', '최대이용금액_카드론_R12M', '이용개월수_신용_R12M', '이용개월수_신판_R12M', '이용개월수_일시불_R12M', '이용개월수_할부_R12M', '이용개월수_할부_유이자_R12M', '이용개월수_할부_무이자_R12M', '이용개월수_부분무이자_R12M', '이용개월수_CA_R12M', '이용개월수_체크_R12M', '이용개월수_카드론_R12M', '이용건수_신용_R6M', '이용건수_신판_R6M', '이용건수_일시불_R6M', '이용건수_할부_R6M', '이용건수_할부_유이자_R6M', '이용건수_할부_무이자_R6M', '이용건수_부분무이자_R6M', '이용건수_CA_R6M', '이용건수_체크_R6M', '이용건수_카드론_R6M', '이용금액_일시불_R6M', '이용금액_할부_R6M', '이용금액_할부_유이자_R6M', '이용금액_할부_무이자_R6M', '이용금액_부분무이자_R6M', '이용금액_CA_R6M', '이용금액_체크_R6M', '이용금액_카드론_R6M', '이용개월수_신용_R6M', '이용개월수_신판_R6M', '이용개월수_일시불_R6M', '이용개월수_할부_R6M', '이용개월수_할부_유이자_R6M', '이용개월수_할부_무이자_R6M', '이용개월수_부분무이자_R6M', '이용개월수_CA_R6M', '이용개월수_체크_R6M', '이용개월수_카드론_R6M', '이용건수_신용_R3M', '이용건수_신판_R3M', '이용건수_일시불_R3M', '이용건수_할부_R3M', '이용건수_할부_유이자_R3M', '이용건수_할부_무이자_R3M', '이용건수_CA_R3M', '이용건수_체크_R3M', '이용건수_카드론_R3M', '이용금액_일시불_R3M', '이용금액_할부_R3M', '이용금액_할부_유이자_R3M', '이용금액_할부_무이자_R3M', '이용금액_부분무이자_R3M', '이용금액_CA_R3M', '이용금액_체크_R3M', '이용금액_카드론_R3M', '이용개월수_신용_R3M', '이용개월수_신판_R3M', '이용개월수_일시불_R3M', '이용개월수_할부_R3M', '이용개월수_할부_유이자_R3M', '이용개월수_할부_무이자_R3M', '이용개월수_CA_R3M', '이용개월수_체크_R3M', '이용개월수_카드론_R3M', '이용가맹점수', '이용금액_해외', '쇼핑_도소매_이용금액', '쇼핑_백화점_이용금액', '쇼핑_마트_이용금액', '쇼핑_슈퍼마켓_이용금액', '쇼핑_편의점_이용금액', '쇼핑_아울렛_이용금액', '쇼핑_온라인_이용금액', '쇼핑_기타_이용금액', '교통_주유이용금액', '교통_정비이용금액', '교통_버스지하철이용금액', '교통_택시이용금액', '교통_철도버스이용금액', '여유_운동이용금액', '여유_Pet이용금액', '여유_공연이용금액', '여유_공원이용금액', '여유_숙박이용금액', '여유_항공이용금액', '여유_기타이용금액', '납부_통신비이용금액', '납부_관리비이용금액', '납부_가스전기료이용금액', '납부_보험료이용금액', '납부_기타이용금액', '_1순위업종', '_1순위업종_이용금액', '_2순위업종', '_2순위업종_이용금액', '_3순위업종', '_3순위업종_이용금액', '_1순위쇼핑업종', '_1순위쇼핑업종_이용금액', '_2순위쇼핑업종', '_2순위쇼핑업종_이용금액', '_3순위쇼핑업종', '_3순위쇼핑업종_이용금액', '_1순위교통업종', '_1순위교통업종_이용금액', '_2순위교통업종', '_2순위교통업종_이용금액', '_3순위교통업종', '_3순위교통업종_이용금액', '_1순위여유업종', '_1순위여유업종_이용금액', '_2순위여유업종', '_2순위여유업종_이용금액', '_3순위여유업종', '_3순위여유업종_이용금액', '_1순위납부업종', '_1순위납부업종_이용금액', '_2순위납부업종', '_2순위납부업종_이용금액', '_3순위납부업종', '_3순위납부업종_이용금액', '할부건수_3M_R12M', '할부건수_6M_R12M', '할부건수_12M_R12M', '할부금액_3M_R12M', '할부금액_6M_R12M', '할부금액_12M_R12M', '할부금액_14M_R12M', '할부건수_유이자_3M_R12M', '할부건수_유이자_6M_R12M', '할부건수_유이자_12M_R12M', '할부금액_유이자_3M_R12M', '할부금액_유이자_6M_R12M', '할부금액_유이자_12M_R12M', '할부금액_유이자_14M_R12M', '할부건수_무이자_3M_R12M', '할부건수_무이자_6M_R12M', '할부건수_무이자_12M_R12M', '할부금액_무이자_3M_R12M', '할부금액_무이자_6M_R12M', '할부금액_무이자_12M_R12M', '할부금액_무이자_14M_R12M', '할부금액_부분_12M_R12M', 'RP건수_B0M', 'RP금액_B0M', 'RP유형건수_B0M', 'RP건수_통신_B0M', 'RP건수_아파트_B0M', 'RP건수_제휴사서비스직접판매_B0M', 'RP건수_렌탈_B0M', 'RP건수_가스_B0M', 'RP건수_전기_B0M', 'RP건수_보험_B0M', 'RP건수_교통_B0M', 'RP후경과월', 'RP후경과월_통신', 'RP후경과월_아파트', 'RP후경과월_제휴사서비스직접판매', 'RP후경과월_렌탈', 'RP후경과월_가스', 'RP후경과월_전기', 'RP후경과월_보험', 'RP후경과월_학습비', 'RP후경과월_교통', '증감_RP건수_전월', '증감_RP유형건수_전월', '증감_RP건수_통신_전월', '증감_RP건수_렌탈_전월', '증감_RP건수_가스_전월', '증감_RP건수_전기_전월', '증감_RP건수_보험_전월', '증감_RP건수_교통_전월', '최초카드론이용경과월', '최종카드론이용경과월', '카드론이용건수_누적', '카드론이용월수_누적', '카드론이용금액_누적', '최종카드론_금융상환방식코드', '최종카드론_신청경로코드', '최종카드론_대출이율', '최종카드론_대출일자', '최종카드론_대출월수', '최종카드론_거치개월수', '최종카드론_대출금액', '이용개월수_온라인_R6M', '이용개월수_오프라인_R6M', '이용금액_온라인_R6M', '이용금액_오프라인_R6M', '이용건수_온라인_R6M', '이용건수_오프라인_R6M', '이용금액_온라인_R3M', '이용금액_오프라인_R3M', '이용건수_온라인_R3 ...

# %% [markdown]
# ### 결측치 처리

# %%
# 전체 행 개수 계산
total_rows = len(df)

# 각 컬럼의 결측치 개수 계산
missing_count = df.isna().sum()

# 결측치 비율 계산 (전체 행 대비 %)
missing_pct = (missing_count / total_rows * 100).round(2)

# 결측치 정보 데이터프레임으로 정리
missing_info = pd.DataFrame({
    'missing_count': missing_count,
    'missing_pct': missing_pct
})

# 결측치가 있는 컬럼만 출력
print("\n결측치 정보 (개수 및 전체 대비 비율 %):")
print(missing_info[missing_info['missing_count'] > 0])
# Out:
# 결측치 정보 (개수 및 전체 대비 비율 %):
#                 missing_count  missing_pct
# _1순위업종                 676567        22.55
# _2순위업종                1143812        38.13
# _3순위업종                1387704        46.26
# _1순위쇼핑업종              1155434        38.51
# _2순위쇼핑업종              1421400        47.38
# _3순위쇼핑업종              1643222        54.77
# _1순위교통업종              1457454        48.58
# _2순위교통업종              2071153        69.04
# _3순위교통업종              2556184        85.21
# _1순위여유업종              2485573        82.85
# _2순위여유업종              2878107        95.94
# _3순위여유업종              2972290        99.08
# _1순위납부업종              1522257        50.74
# _2순위납부업종              2543911        84.80
# _3순위납부업종              2888898        96.30
# 최종카드론_금융상환방식코드        2447897        81.60
# 최종카드론_신청경로코드          2448009        81.60
# 최종카드론_대출일자            2485868        82.86
# Segment                600000        20.00

# %% [markdown]
# ### 날짜형, 순서형, 수치형 컬럼 찾아서 분리 후 처리하기

# %%
# 검사할 컬럼 리스트
c1 = list (df.columns)
cols_to_check = c1

# 비수치형 컬럼 저장용 리스트
non_numeric_cols = []

# 각 컬럼에 대해 수치형 변환 시도 후 NaN 비율로 판단
for col in cols_to_check:
    # 결측을 빈 문자열로, 나머지를 문자열로 변환
    s = df[col].fillna('').astype(str)
    # 숫자로 변환 (불가능한 항목은 NaN)
    num = pd.to_numeric(s, errors='coerce')
    # 변환 불가 비율 계산
    na_ratio = num.isna().mean()
    # 일정 비율 이상이면 비수치형으로 간주 (여기선 100% 미수치형도 포함)
    if na_ratio > 0:
        non_numeric_cols.append(col)

# 결과 출력
print("비수치형(또는 혼합형) 컬럼:", non_numeric_cols)
# Out:
# 비수치형(또는 혼합형) 컬럼: ['ID', '_1순위업종', '_2순위업종', '_3순위업종', '_1순위쇼핑업종', '_2순위쇼핑업종', '_3순위쇼핑업종', '_1순위교통업종', '_2순위교통업종', '_3순위교통업종', '_1순위여유업종', '_2순위여유업종', '_3순위여유업종', '_1순위납부업종', '_2순위납부업종', '_3순위납부업종', '최종카드론_금융상환방식코드', '최종카드론_신청경로코드', '최종카드론_대출일자', '이용금액대', 'Segment']

# %%
# 각 컬럼별 분포(value_counts) 출력
c1 = list (df.columns)
for col in c1:
    print(f"▶ [{col}] 분포")
    print(df[col].value_counts(dropna=False))
    print()  # 빈 줄로 구분
# Out:
# ▶ [기준년월] 분포
# 기준년월
# 201807    500000
# 201808    500000
# 201809    500000
# 201810    500000
# 201811    500000
# 201812    500000
# Name: count, dtype: int64
#
# ▶ [ID] 분포
# ID
# TRAIN_000000    6
# TRAIN_333343    6
# TRAIN_333341    6
# TRAIN_333340    6
# TRAIN_333339    6
#                ..
# TRAIN_166662    6
# TRAIN_166661    6
# TRAIN_166660    6
# TRAIN_166659    6
# TEST_99999      6
# Name: count, Length: 500000, dtype: int64
#
# ▶ [최종이용일자_기본] 분포
# 최종이용일자_기본
# 20180731    149387
# 20180930    127899
# 20180831    125873
# 20181130    117204
# 10101       116608
#              ...
# 20160120         1
# 20160126         1
# 20141216         1
# 20151208         1
# 20151121         1
# Name: count, Length: 1292, dtype: int64
#
# ▶ [최종이용일자_신판] 분포
# 최종이용일자_신판
# 20180731    149641
# 20180930    128068
# 20180831    126047
# 10101       117610
# 20181130    117247
#              ...
# 20160120         1
# 20151208         1
# 20151101         1
# 20151206         1
# 20151029         1
# Name: count, Length: 1277, dtype: int64
#
# ▶ [최종이용일자_CA] 분포
# 최종이용일자_CA
# 10101       2043433
# 20180629       3125
# 20180630       2944
# 20180628       2788
# 20180627       2756
#              ...
# 20110722          6
# 20100504          6
# 20101031          6
# 20100910          6
# 20181231          1
# Name: count, Length: 3154, dtype: int64
#
# ▶ [최종이용일자_카드론] 분포
# 최종이용일자_카드론
# 10101       2485868
# 20180406       1392
# 20180407       1391
# 20180404       1374
# 20180413       1344
#              ...
# 20180911          4
# 20181014          3
# 20181126          2
# 20181215          1
# 20181212          1
# Name: count, Length: 1684, dtype: int64
#
# ▶ [최종이용일자_체크] 분포
# 최종이용일자_체크
# 10101       1897000
# 20181231      35428
# 20181130      35093
# 20181031      32543
# 20180930      31782
#              ...
# 20121219          6
# 20121004          6
# 20160501          6
# 20160604          3
# 20160923          1
# Name: count, Length: 2259, dtype: int64
#
# ▶ [최종이용일자_일시불] 분포
# 최종이용일자_일시불
# 20180731    150371
# 20180930    127749
# 20180831    126300
# 10101       123459
# 20181130    116810
#              ...
# 20160211         6
# 20160207         6
# 20160214         4
# 20160219         4
# 20160210         4
# Name: count, Length: 1088, dtype: int64
#
# ▶ [최종이용일자_할부] 분포
# 최종이용일자_할부
# 10101       834228
# 20180629     13686
# 20180628     13247
# 20180630     13109
# 20180626     12540
#              ...
# 20120731         6
# 20120703         6
# 20110525         6
# 20120625         6
# 20181231         4
# Name: count, Length: 2281, dtype: int64
#
# ▶ [이용건수_신용_B0M] 분포
# 이용건수_신용_B0M
#  0     248604
# -1     240443
#  1     203223
# -2     164881
#  2     152533
#         ...
#  86       315
#  87       124
#  88        23
#  89         4
#  90         1
# Name: count, Length: 94, dtype: int64
#
# ▶ [이용건수_신판_B0M] 분포
# 이용건수_신판_B0M
#  0     250116
# -1     241586
#  1     204493
# -2     167955
#  2     153337
#         ...
#  85       702
#  86       284
#  87       114
#  88        20
#  89         3
# Name: count, Length: 93, dtype: int64
#
# ▶ [이용건수_일시불_B0M] 분포
# 이용건수_일시불_B0M
#  0     251687
# -1     242736
#  1     205805
# -2     168070
#  2     154596
#         ...
#  84      1042
#  85       453
#  86       147
#  87        33
#  88         2
# Name: count, Length: 92, dtype: int64
#
# ▶ [이용건수_할부_B0M] 분포
# 이용건수_할부_B0M
# 0    2655225
# 1     257901
# 2      78330
# 3       8544
# Name: count, dtype: int64
#
# ▶ [이용건수_할부_유이자_B0M] 분포
# 이용건수_할부_유이자_B0M
# 0    2916426
# 1      83574
# Name: count, dtype: int64
#
# ▶ [이용건수_할부_무이자_B0M] 분포
# 이용건수_할부_무이자_B0M
# 0    2690201
# 1     262979
# 2      46820
# Name: count, dtype: int64
#
# ▶ [이용건수_CA_B0M] 분포
# 이용건수_CA_B0M
# 0    2876426
# 2     121822
# 1       1618
# 3        134
# Name: count, dtype: int64
#
# ▶ [이용건수_체크_B0M] 분포
# 이용건수_체크_B0M
# 0     2609465
# 12      20891
# 13      20588
# 11      20562
# 10      19211
#        ...
# 66        114
# 67         57
# 68         14
# 69          7
# 70          4
# Name: count, Length: 72, dtype: int64
#
# ▶ [이용금액_일시불_B0M] 분포
# 이용금액_일시불_B0M
# 0        717744
# 2055        378
# 2040        366
# 1731        365
# 2008        355
#           ...
# 28691         1
# 26103         1
# 27263         1
# 27410         1
# 27438         1
# Name: count, Length: 29448, dtype: int64
#
# ▶ [이용금액_할부_B0M] 분포
# 이용금액_할부_B0M
# 0        2745197
# 4514         159
# 4097         158
# 4296         157
# 4352         156
#           ...
# 10978          1
# 10596          1
# 11871          1
# 10777          1
# 2622           1
# Name: count, Length: 9142, dtype: int64
#
# ▶ [이용금액_할부_유이자_B0M] 분포
# 이용금액_할부_유이자_B0M
# 0       2926858
# 4498         99
# 4418         89
# 4636         85
# 4359         84
#          ...
# 6220          1
# 6062          1
# 1888          1
# 6457          1
# 3101          1
# Name: count, Length: 3366, dtype: int64
#
# ▶ [이용금액_할부_무이자_B0M] 분포
# 이용금액_할부_무이자_B0M
# 0       2786985
# 4097        164
# 4186        154
# 4088        152
# 3960        152
#          ...
# 7823          1
# 2588          1
# 7111          1
# 2376          1
# 2673          1
# Name: count, Length: 5130, dtype: int64
#
# ▶ [이용금액_CA_B0M] 분포
# 이용금액_CA_B0M
# 0        2876434
# 6763          38
# 7092          31
# 7255          30
# 7921          30
#           ...
# 24205          1
# 23427          1
# 20460          1
# 4844           1
# 20285          1
# Name: count, Length: 16694, dtype: int64
#
# ▶ [이용금액_체크_B0M] 분포
# 이용금액_체크_B0M
#  0        2608249
#  2845         130
#  2951         126
#  3078         124
#  2700         122
#            ...
#  70             1
#  71             1
#  14195          1
# -486            1
#  13440          1
# Name: count, Length: 15004, dtype: int64
#
# ▶ [이용후경과월_신용] 분포
# 이용후경과월_신용
# 0     1595287
# 1      478298
# 12     369926
# 2      177461
# 3       89183
# 4       63413
# 8       47190
# 5       41219
# 7       34660
# 9       33153
# 6       31189
# 10      22791
# 11      16230
# Name: count, dtype: int64
#
# ▶ [이용후경과월_신판] 분포
# 이용후경과월_신판
# 0     1535427
# 1      500608
# 12     379344
# 2      189254
# 3       93346
# 4       66405
# 8       51467
# 5       42256
# 7       35873
# 9       34458
# 6       31386
# 10      23407
# 11      16769
# Name: count, dtype: int64
#
# ▶ [이용후경과월_일시불] 분포
# 이용후경과월_일시불
# 0     2165578
# 12     354493
# 1      169048
# 2       96831
# 3       61525
# 4       42473
# 5       27148
# 6       16215
# 10      14007
# 9       13789
# 7       13230
# 11      12916
# 8       12747
# Name: count, dtype: int64
#
# ▶ [이용후경과월_할부] 분포
# 이용후경과월_할부
# 12    1614631
# 1      319044
# 8      190093
# 2      162931
# 0      155125
# 4      143512
# 3      142214
# 7       95225
# 9       76009
# 5       53596
# 6       46686
# 10        933
# 11          1
# Name: count, dtype: int64
#
# ▶ [이용후경과월_할부_유이자] 분포
# 이용후경과월_할부_유이자
# 12    2364577
# 8      106666
# 1      102905
# 2       90639
# 3       71156
# 7       58579
# 4       54398
# 9       46720
# 0       35121
# 5       34821
# 6       33631
# 10        787
# Name: count, dtype: int64
#
# ▶ [이용후경과월_할부_무이자] 분포
# 이용후경과월_할부_무이자
# 12    1732537
# 1      275923
# 8      172371
# 2      150010
# 3      142832
# 4      141526
# 0      126081
# 7      100240
# 5       54954
# 9       52582
# 6       50575
# 10        368
# 11          1
# Name: count, dtype: int64
#
# ▶ [이용후경과월_부분무이자] 분포
# 이용후경과월_부분무이자
# 12    2946741
# 2       26014
# 5       12911
# 6        5532
# 7        2629
# 1        1740
# 8        1421
# 4        1341
# 3         814
# 9         353
# 11        286
# 10        211
# 0           7
# Name: count, dtype: int64
#
# ▶ [이용후경과월_CA] 분포
# 이용후경과월_CA
# 12    2692765
# 0      123574
# 6       25296
# 5       24495
# 4       23628
# 3       22083
# 2       18464
# 7       17694
# 1       13819
# 8       12621
# 9        9362
# 10       8310
# 11       7889
# Name: count, dtype: int64
#
# ▶ [이용후경과월_체크] 분포
# 이용후경과월_체크
# 12    2442414
# 0      390370
# 6       20975
# 7       19954
# 5       18913
# 8       17875
# 4       16560
# 9       15690
# 3       13383
# 10      13079
# 11      11025
# 2       10573
# 1        9189
# Name: count, dtype: int64
#
# ▶ [이용후경과월_카드론] 분포
# 이용후경과월_카드론
# 12    2852652
# 6       18928
# 7       17936
# 8       17525
# 5       17120
# 4       15786
# 9       14018
# 3       12277
# 10      11656
# 11      11188
# 2        6894
# 1        3899
# 0         121
# Name: count, dtype: int64
#
# ▶ [이용건수_신용_R12M] 분포
# 이용건수_신용_R12M
#  0       346828
# -1       330691
#  3        28693
#  2        19192
#  4        16123
#           ...
#  1020         1
#  1017         1
#  1027         1
#  1022         1
#  1033         1
# Name: count, Length: 1034, dtype: int64
#
# ▶ [이용건수_신판_R12M] 분포
# 이용건수_신판_R12M
#  0       355028
# -1       345885
#  3        28996
#  2        17845
#  4        14826
#           ...
#  1029         1
#  1034         1
#  1020         1
#  1022         1
#  1033         1
# Name: count, Length: 1030, dtype: int64
#
# ▶ [이용건수_일시불_R12M] 분포
# 이용건수_일시불_R12M
# -1       406651
#  0       360667
#  16       10371
#  17       10264
#  11       10185
#           ...
#  998          2
#  997          2
#  999          1
#  1002         1
#  1003         1
# Name: count, Length: 1007, dtype: int64
#
# ▶ [이용건수_할부_R12M] 분포
# 이용건수_할부_R12M
# 0     2095606
# 4      245610
# 3       88402
# 8       65477
# 7       59993
#        ...
# 61          9
# 63          8
# 67          2
# 66          2
# 65          1
# Name: count, Length: 67, dtype: int64
#
# ▶ [이용건수_할부_유이자_R12M] 분포
# 이용건수_할부_유이자_R12M
# 0     2683341
# 4      134891
# 3       52148
# 5       32243
# 7       16351
# 6       15205
# 8       14818
# 9       13393
# 10       8999
# 11       6874
# 12       6187
# 13       5211
# 14       3686
# 15       2131
# 16       1410
# 17       1074
# 18        711
# 19        467
# 20        323
# 21        210
# 22        155
# 23         89
# 24         38
# 25         23
# 26         10
# 2           6
# 27          3
# 30          2
# 28          1
# Name: count, dtype: int64
#
# ▶ [이용건수_할부_무이자_R12M] 분포
# 이용건수_할부_무이자_R12M
# 0     2149870
# 4      264966
# 3       87392
# 5       74644
# 7       60211
#        ...
# 58          7
# 56          4
# 59          3
# 60          2
# 61          1
# Name: count, Length: 61, dtype: int64
#
# ▶ [이용건수_CA_R12M] 분포
# 이용건수_CA_R12M
# 0     2633595
# 3       53601
# 2       46292
# 4       44343
# 5       29269
# 1       25848
# 6       18094
# 7       12612
# 8       10465
# 9        9672
# 10       9255
# 11       9179
# 12       9037
# 13       8809
# 14       8572
# 15       8279
# 16       7922
# 17       7695
# 18       7308
# 19       6896
# 20       6476
# 21       6155
# 22       5346
# 23       4841
# 24       3954
# 25       3108
# 26       1978
# 27       1028
# 28        321
# 29         46
# 30          4
# Name: count, dtype: int64
#
# ▶ [이용건수_체크_R12M] 분포
# 이용건수_체크_R12M
#  0      2350410
# -1        71444
#  36        3596
#  30        3592
#  29        3576
#          ...
#  703          1
#  705          1
#  701          1
#  693          1
#  702          1
# Name: count, Length: 703, dtype: int64
#
# ▶ [이용건수_카드론_R12M] 분포
# 이용건수_카드론_R12M
# 0    2837732
# 2      79905
# 1      79183
# 3       3180
# Name: count, dtype: int64
#
# ▶ [이용금액_일시불_R12M] 분포
# 이용금액_일시불_R12M
# 0         351263
# 3004         100
# 3869          98
# 4003          98
# 2788          97
#            ...
# 315984         1
# 473965         1
# 231649         1
# 196607         1
# 423882         1
# Name: count, Length: 279319, dtype: int64
#
# ▶ [이용금액_할부_R12M] 분포
# 이용금액_할부_R12M
# 0         1651820
# 3569          739
# 3568          735
# 3567          728
# 3570          603
#            ...
# 86509           1
# 41867           1
# 92579           1
# 62586           1
# 103516          1
# Name: count, Length: 83329, dtype: int64
#
# ▶ [이용금액_할부_유이자_R12M] 분포
# 이용금액_할부_유이자_R12M
# 0        2379772
# 4174         249
# 4132         248
# 4160         242
# 4070         237
#           ...
# 46090          1
# 33094          1
# 45628          1
# 48994          1
# 29711          1
# Name: count, Length: 37976, dtype: int64
#
# ▶ [이용금액_할부_무이자_R12M] 분포
# 이용금액_할부_무이자_R12M
# 0         1774660
# 3569          773
# 3567          767
# 3568          766
# 3570          636
#            ...
# 92567           1
# 173783          1
# 58935           1
# 53975           1
# 86775           1
# Name: count, Length: 71947, dtype: int64
#
# ▶ [이용금액_부분무이자_R12M] 분포
# 이용금액_부분무이자_R12M
# 0        2940494
# 7976          75
# 7815          68
# 7820          66
# 7938          65
#           ...
# 9938           1
# 10239          1
# 9617           1
# 18279          1
# 5881           1
# Name: count, Length: 3601, dtype: int64
#
# ▶ [이용금액_CA_R12M] 분포
# 이용금액_CA_R12M
# 0         2620087
# 960000        127
# 5445           49
# 5029           48
# 4995           48
#            ...
# 79131           1
# 43304           1
# 254748          1
# 413605          1
# 307192          1
# Name: count, Length: 125919, dtype: int64
#
# ▶ [이용금액_체크_R12M] 분포
# 이용금액_체크_R12M
# -414      1163697
#  0            804
# -390          448
#  223          441
# -280          440
#            ...
#  51760          1
#  55511          1
#  57364          1
#  58933          1
#  60818          1
# Name: count, Length: 82197, dtype: int64
#
# ▶ [이용금액_카드론_R12M] 분포
# 이용금액_카드론_R12M
# 0         2859630
# 46808          85
# 46596          83
# 46898          81
# 46728          79
#            ...
# 143445          1
# 145899          1
# 142423          1
# 140812          1
# 143357          1
# Name: count, Length: 15443, dtype: int64
#
# ▶ [최대이용금액_일시불_R12M] 분포
# 최대이용금액_일시불_R12M
# 0         350831
# 14          6758
# 15          6482
# 13          6111
# 16          6026
#            ...
# 54961          1
# 108514         1
# 88589          1
# 62415          1
# 130090         1
# Name: count, Length: 89273, dtype: int64
#
# ▶ [최대이용금액_할부_R12M] 분포
# 최대이용금액_할부_R12M
# 0        1651565
# 5607         190
# 5483         187
# 5133         186
# 4350         183
#           ...
# 30290          1
# 26826          1
# 35049          1
# 27779          1
# 25539          1
# Name: count, Length: 32298, dtype: int64
#
# ▶ [최대이용금액_할부_유이자_R12M] 분포
# 최대이용금액_할부_유이자_R12M
# 0        2366540
# 4742         133
# 4850         128
# 3725         128
# 4385         127
#           ...
# 23816          1
# 20969          1
# 17194          1
# 20786          1
# 16770          1
# Name: count, Length: 20637, dtype: int64
#
# ▶ [최대이용금액_할부_무이자_R12M] 분포
# 최대이용금액_할부_무이자_R12M
# 0        1798196
# 4445         159
# 5414         154
# 4553         152
# 4835         151
#           ...
# 27229          1
# 32974          1
# 31096          1
# 27600          1
# 25539          1
# Name: count, Length: 32298, dtype: int64
#
# ▶ [최대이용금액_부분무이자_R12M] 분포
# 최대이용금액_부분무이자_R12M
# 0       2939449
# 7265         67
# 7287         67
# 7311         64
# 7215         64
#          ...
# 9599          1
# 9065          1
# 8991          1
# 5999          1
# 6076          1
# Name: count, Length: 3654, dtype: int64
#
# ▶ [최대이용금액_CA_R12M] 분포
# 최대이용금액_CA_R12M
# 0        2620100
# 3345          89
# 3727          88
# 3719          87
# 3897          85
#           ...
# 56262          1
# 36885          1
# 75893          1
# 31895          1
# 46443          1
# Name: count, Length: 47734, dtype: int64
#
# ▶ [최대이용금액_체크_R12M] 분포
# 최대이용금액_체크_R12M
# 0        2347648
# 1018         381
# 978          380
# 1032         376
# 1010         375
#           ...
# 26075          1
# 59195          1
# 51919          1
# 14138          1
# 38014          1
# Name: count, Length: 53011, dtype: int64
#
# ▶ [최대이용금액_카드론_R12M] 분포
# 최대이용금액_카드론_R12M
# 0         2867381
# 20736          98
# 20784          94
# 20804          87
# 20851          85
#            ...
# 78503           1
# 78475           1
# 190915          1
# 23727           1
# 78633           1
# Name: count, Length: 20077, dtype: int64
#
# ▶ [이용개월수_신용_R12M] 분포
# 이용개월수_신용_R12M
# 12    1566654
# 0      335060
# 10     223087
# 9      178811
# 8      104797
# 2      100279
# 3       91625
# 7       80703
# 5       78953
# 4       78672
# 6       75472
# 11      48380
# 1       37507
# Name: count, dtype: int64
#
# ▶ [이용개월수_신판_R12M] 분포
# 이용개월수_신판_R12M
# 12    1561238
# 0      341141
# 10     199285
# 9      183557
# 8      111651
# 2      102113
# 3       91544
# 7       82412
# 4       78536
# 5       78383
# 6       75308
# 11      47980
# 1       46852
# Name: count, dtype: int64
#
# ▶ [이용개월수_일시불_R12M] 분포
# 이용개월수_일시불_R12M
# 12    1554136
# 0      355464
# 10     205631
# 9      175135
# 8      107082
# 2       98691
# 3       90632
# 7       83297
# 5       81088
# 4       79917
# 6       77473
# 11      48174
# 1       43280
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_R12M] 분포
# 이용개월수_할부_R12M
# 0     1604923
# 1      378441
# 2      246872
# 3      168608
# 4      119722
# 5       90771
# 8       79091
# 10      78213
# 6       76074
# 7       74550
# 9       73840
# 11       8895
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_유이자_R12M] 분포
# 이용개월수_할부_유이자_R12M
# 0    2349313
# 1     298819
# 2     161425
# 3      97460
# 4      91004
# 5       1979
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_무이자_R12M] 분포
# 이용개월수_할부_무이자_R12M
# 0     1731929
# 1      351253
# 2      244356
# 3      170940
# 4      113396
# 5       84002
# 7       83825
# 6       76486
# 8       74313
# 9       69499
# 10          1
# Name: count, dtype: int64
#
# ▶ [이용개월수_부분무이자_R12M] 분포
# 이용개월수_부분무이자_R12M
# 0    2939882
# 1      60118
# Name: count, dtype: int64
#
# ▶ [이용개월수_CA_R12M] 분포
# 이용개월수_CA_R12M
# 0     2623287
# 2      105798
# 3       53715
# 1       38765
# 8       37216
# 7       33563
# 4       24615
# 6       23153
# 9       23070
# 5       20235
# 12      11532
# 10       4946
# 11        105
# Name: count, dtype: int64
#
# ▶ [이용개월수_체크_R12M] 분포
# 이용개월수_체크_R12M
# 0     2348237
# 12     205745
# 3      120084
# 8      101098
# 7       62656
# 4       46074
# 2       38172
# 6       24431
# 9       24268
# 5       22946
# 1        5838
# 10        451
# Name: count, dtype: int64
#
# ▶ [이용개월수_카드론_R12M] 분포
# 이용개월수_카드론_R12M
# 0    2843188
# 1     151188
# 2       5624
# Name: count, dtype: int64
#
# ▶ [이용건수_신용_R6M] 분포
# 이용건수_신용_R6M
# -2      295938
# -1       62553
#  0       58679
#  1       53460
#  2       47593
#          ...
#  547         1
#  542         1
#  548         1
#  545         1
#  539         1
# Name: count, Length: 564, dtype: int64
#
# ▶ [이용건수_신판_R6M] 분포
# 이용건수_신판_R6M
# -2      303051
# -1       63795
#  0       59114
#  1       53476
#  2       47688
#          ...
#  545         1
#  548         1
#  542         1
#  547         1
#  539         1
# Name: count, Length: 564, dtype: int64
#
# ▶ [이용건수_일시불_R6M] 분포
# 이용건수_일시불_R6M
# -2      338160
# -1       55554
#  0       53286
#  1       49314
#  2       45533
#          ...
#  531         6
#  533         4
#  537         1
#  536         1
#  535         1
# Name: count, Length: 555, dtype: int64
#
# ▶ [이용건수_할부_R6M] 분포
# 이용건수_할부_R6M
#  0     2153243
#  1      215677
#  2      146552
#  3       90865
#  6       70336
#  4       64087
#  5       55854
#  7       41435
#  8       30150
#  12      24440
#  9       20907
#  10      16404
#  11      16168
#  13      11080
#  16       7921
#  14       7753
#  15       7447
#  17       7408
#  18       5218
#  19       2924
#  20       1759
# -1        1288
#  21        801
#  22        235
#  23         42
#  24          6
# Name: count, dtype: int64
#
# ▶ [이용건수_할부_유이자_R6M] 분포
# 이용건수_할부_유이자_R6M
#  0    2679100
#  1     148399
#  2      62208
#  3      31524
#  5      28530
#  4      28473
#  6      17184
# -1       4582
# Name: count, dtype: int64
#
# ▶ [이용건수_할부_무이자_R6M] 분포
# 이용건수_할부_무이자_R6M
#  0     2237185
#  1      196910
#  2      150225
#  3       94172
#  6       69174
#  4       55878
#  5       47028
#  7       36863
#  8       23945
#  12      19964
#  9       12917
#  11      11788
#  10      10714
#  15       6651
#  16       6469
#  14       6225
#  13       5830
#  17       4875
#  18       1953
# -1        1032
#  19        201
#  20          1
# Name: count, dtype: int64
#
# ▶ [이용건수_부분무이자_R6M] 분포
# 이용건수_부분무이자_R6M
# 0    2988280
# 1      11720
# Name: count, dtype: int64
#
# ▶ [이용건수_CA_R6M] 분포
# 이용건수_CA_R6M
# 0     2770549
# 2       42142
# 3       28467
# 12      27659
# 1       18382
# 10      16647
# 9       15756
# 4       15584
# 11      14162
# 8       11694
# 6       10753
# 5       10515
# 7        9281
# 13       5928
# 14       2053
# 15        401
# 16         23
# 18          2
# 17          2
# Name: count, dtype: int64
#
# ▶ [이용건수_체크_R6M] 분포
# 이용건수_체크_R6M
#  0      2495938
# -1        30521
#  13        4285
#  15        4205
#  10        4171
#          ...
#  409          1
#  402          1
# -6            1
#  404          1
#  401          1
# Name: count, Length: 411, dtype: int64
#
# ▶ [이용건수_카드론_R6M] 분포
# 이용건수_카드론_R6M
# 0    2947198
# 1      52579
# 2        223
# Name: count, dtype: int64
#
# ▶ [이용금액_일시불_R6M] 분포
# 이용금액_일시불_R6M
#  0         339255
# -11655       3406
# -724          182
# -637          181
# -625          178
#             ...
#  119154         1
#  72205          1
#  142985         1
#  115495         1
#  144181         1
# Name: count, Length: 148969, dtype: int64
#
# ▶ [이용금액_할부_R6M] 분포
# 이용금액_할부_R6M
#  0        1441437
# -5           8907
# -6           8811
# -4           8762
# -3           8604
#            ...
# -4503           1
#  35238          1
#  52214          1
#  45898          1
#  36883          1
# Name: count, Length: 57719, dtype: int64
#
# ▶ [이용금액_할부_유이자_R6M] 분포
# 이용금액_할부_유이자_R6M
#  0        2702740
#  4800          54
#  4984          54
#  4674          53
#  5154          51
#            ...
#  30528          1
# -7281           1
#  1061           1
#  33215          1
#  26703          1
# Name: count, Length: 35986, dtype: int64
#
# ▶ [이용금액_할부_무이자_R6M] 분포
# 이용금액_할부_무이자_R6M
#  0        2262609
#  4824          96
#  5135          91
#  5144          88
#  4867          88
#            ...
#  41186          1
#  34133          1
#  44857          1
# -5091           1
#  36195          1
# Name: count, Length: 46324, dtype: int64
#
# ▶ [이용금액_부분무이자_R6M] 분포
# 이용금액_부분무이자_R6M
#  0        2009307
# -5          10512
# -6          10433
# -4          10410
# -3          10322
#            ...
#  2066           1
#  10998          1
#  1402           1
#  9482           1
#  1738           1
# Name: count, Length: 4625, dtype: int64
#
# ▶ [이용금액_CA_R6M] 분포
# 이용금액_CA_R6M
# 0         2767092
# 4825           32
# 3956           30
# 4091           29
# 4651           29
#            ...
# 49279           1
# 69560           1
# 92067           1
# 145040          1
# 102201          1
# Name: count, Length: 88352, dtype: int64
#
# ▶ [이용금액_체크_R6M] 분포
# 이용금액_체크_R6M
#  0        2492719
# -547        23717
# -758         1148
#  2770          36
#  2702          36
#            ...
#  76951          1
#  40610          1
#  57500          1
#  45205          1
#  46338          1
# Name: count, Length: 77006, dtype: int64
#
# ▶ [이용금액_카드론_R6M] 분포
# 이용금액_카드론_R6M
# 0        2944308
# 73411          8
# 74744          8
# 47528          8
# 47886          7
#           ...
# 44037          1
# 64201          1
# 88343          1
# 67998          1
# 68973          1
# Name: count, Length: 34203, dtype: int64
#
# ▶ [이용개월수_신용_R6M] 분포
# 이용개월수_신용_R6M
# 6    2070700
# 0     501210
# 5     117034
# 1      93370
# 4      84580
# 2      68417
# 3      64689
# Name: count, dtype: int64
#
# ▶ [이용개월수_신판_R6M] 분포
# 이용개월수_신판_R6M
# 6    2057626
# 0     505739
# 5     121170
# 1      94026
# 4      85549
# 2      69753
# 3      66137
# Name: count, dtype: int64
#
# ▶ [이용개월수_일시불_R6M] 분포
# 이용개월수_일시불_R6M
# 6    2051052
# 0     518717
# 5     123362
# 1      87224
# 4      84905
# 2      69040
# 3      65700
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_R6M] 분포
# 이용개월수_할부_R6M
# 0    2078752
# 1     363062
# 2     198463
# 4     159683
# 6     106846
# 3      59729
# 5      33465
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_유이자_R6M] 분포
# 이용개월수_할부_유이자_R6M
# 0    2661290
# 1     227951
# 2      56474
# 3      38536
# 4      14392
# 5       1154
# 6        203
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_무이자_R6M] 분포
# 이용개월수_할부_무이자_R6M
# 0    2175615
# 1     359243
# 2     181172
# 4     139192
# 6      76798
# 3      60559
# 5       7421
# Name: count, dtype: int64
#
# ▶ [이용개월수_부분무이자_R6M] 분포
# 이용개월수_부분무이자_R6M
# 0    2986930
# 1      13070
# Name: count, dtype: int64
#
# ▶ [이용개월수_CA_R6M] 분포
# 이용개월수_CA_R6M
# 0    2743948
# 1     106222
# 6      65744
# 3      35418
# 4      24072
# 5      17456
# 2       7140
# Name: count, dtype: int64
#
# ▶ [이용개월수_체크_R6M] 분포
# 이용개월수_체크_R6M
# 0    2484322
# 6     305983
# 1     107239
# 5      65860
# 4      28741
# 2       4981
# 3       2874
# Name: count, dtype: int64
#
# ▶ [이용개월수_카드론_R6M] 분포
# 이용개월수_카드론_R6M
# 0    2935251
# 1      64728
# 2         21
# Name: count, dtype: int64
#
# ▶ [이용건수_신용_R3M] 분포
# 이용건수_신용_R3M
#  0      259171
# -2      130108
# -1       80062
#  1       74165
#  2       67389
#          ...
#  284         6
#  283         5
#  285         4
#  286         3
#  288         1
# Name: count, Length: 297, dtype: int64
#
# ▶ [이용건수_신판_R3M] 분포
# 이용건수_신판_R3M
#  0      263264
# -2      131842
# -1       80967
#  1       74703
#  2       66992
#          ...
#  283         6
#  286         2
#  284         2
#  285         1
#  288         1
# Name: count, Length: 297, dtype: int64
#
# ▶ [이용건수_일시불_R3M] 분포
# 이용건수_일시불_R3M
#  0      267215
# -2      137800
# -1       80215
#  1       72385
#  2       66601
#          ...
#  279        12
#  280        10
#  281         6
#  282         2
#  284         1
# Name: count, Length: 293, dtype: int64
#
# ▶ [이용건수_할부_R3M] 분포
# 이용건수_할부_R3M
#  0     2480052
#  3      157115
#  1      137476
#  2       90327
#  6       53914
#  4       34914
#  5       29600
#  7        8667
#  8        3946
#  9        3861
# -1         127
#  10          1
# Name: count, dtype: int64
#
# ▶ [이용건수_할부_유이자_R3M] 분포
# 이용건수_할부_유이자_R3M
#  0    2840159
#  1      68487
#  3      53858
#  2      37377
# -1        119
# Name: count, dtype: int64
#
# ▶ [이용건수_할부_무이자_R3M] 분포
# 이용건수_할부_무이자_R3M
#  0    2531086
#  3     160902
#  1     140803
#  2      80827
#  6      35406
#  4      25889
#  5      24148
# -1        939
# Name: count, dtype: int64
#
# ▶ [이용건수_CA_R3M] 분포
# 이용건수_CA_R3M
# 0    2842389
# 6      80613
# 2      27267
# 4      15332
# 3      14236
# 5       9559
# 1       7003
# 7       3083
# 8        509
# 9          9
# Name: count, dtype: int64
#
# ▶ [이용건수_체크_R3M] 분포
# 이용건수_체크_R3M
#  0      2571722
# -1         9894
#  30        6480
#  31        6414
#  32        6397
#          ...
#  204          3
#  207          1
#  206          1
#  205          1
#  209          1
# Name: count, Length: 212, dtype: int64
#
# ▶ [이용건수_카드론_R3M] 분포
# 이용건수_카드론_R3M
# 0    2989747
# 1      10253
# Name: count, dtype: int64
#
# ▶ [이용금액_일시불_R3M] 분포
# 이용금액_일시불_R3M
#  0        450280
# -596         233
# -289         226
# -362         221
# -517         220
#            ...
#  84157         1
# -7192          1
#  71887         1
# -7214          1
#  64786         1
# Name: count, Length: 82714, dtype: int64
#
# ▶ [이용금액_할부_R3M] 분포
# 이용금액_할부_R3M
#  0        1815936
# -5           8919
# -6           8806
# -4           8769
# -3           8609
#            ...
#  30119          1
#  21224          1
#  34598          1
#  25156          1
#  32552          1
# Name: count, Length: 31223, dtype: int64
#
# ▶ [이용금액_할부_유이자_R3M] 분포
# 이용금액_할부_유이자_R3M
#  0        2855049
#  4937          46
#  4712          40
#  4832          39
#  4466          39
#            ...
# -200            1
#  2806           1
# -1461           1
# -1406           1
#  17095          1
# Name: count, Length: 17307, dtype: int64
#
# ▶ [이용금액_할부_무이자_R3M] 분포
# 이용금액_할부_무이자_R3M
#  0        2618751
#  4740          78
#  4775          75
#  4293          72
#  4019          71
#            ...
# -2116           1
#  21779          1
#  19995          1
#  735            1
#  21898          1
# Name: count, Length: 21795, dtype: int64
#
# ▶ [이용금액_부분무이자_R3M] 분포
# 이용금액_부분무이자_R3M
#  0       2020611
# -5         10512
# -6         10433
# -4         10410
# -3         10322
#           ...
#  1925          1
#  2191          1
#  2500          1
#  2490          1
#  1738          1
# Name: count, Length: 2646, dtype: int64
#
# ▶ [이용금액_CA_R3M] 분포
# 이용금액_CA_R3M
# 0        2842239
# 6473          17
# 7073          17
# 6129          17
# 5647          17
#           ...
# 62700          1
# 42668          1
# 52865          1
# 31791          1
# 60806          1
# Name: count, Length: 53235, dtype: int64
#
# ▶ [이용금액_체크_R3M] 분포
# 이용금액_체크_R3M
#  0        2569172
# -758         5102
#  6822          51
#  7876          48
#  7975          47
#            ...
#  37909          1
#  32432          1
#  38794          1
#  41623          1
#  33094          1
# Name: count, Length: 42611, dtype: int64
#
# ▶ [이용금액_카드론_R3M] 분포
# 이용금액_카드론_R3M
# 0        2988745
# 73411          8
# 72047          6
# 70113          6
# 69805          6
#           ...
# 87705          1
# 80561          1
# 78691          1
# 71719          1
# 74425          1
# Name: count, Length: 8777, dtype: int64
#
# ▶ [이용개월수_신용_R3M] 분포
# 이용개월수_신용_R3M
# 3    2232584
# 0     616184
# 2      76021
# 1      75211
# Name: count, dtype: int64
#
# ▶ [이용개월수_신판_R3M] 분포
# 이용개월수_신판_R3M
# 3    2220235
# 0     623672
# 2      78415
# 1      77678
# Name: count, dtype: int64
#
# ▶ [이용개월수_일시불_R3M] 분포
# 이용개월수_일시불_R3M
# 3    2211376
# 0     634198
# 2      79837
# 1      74589
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_R3M] 분포
# 이용개월수_할부_R3M
# 0    2381060
# 1     289415
# 2     174615
# 3     154910
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_유이자_R3M] 분포
# 이용개월수_할부_유이자_R3M
# 0    2776404
# 1     165035
# 2      54549
# 3       4012
# Name: count, dtype: int64
#
# ▶ [이용개월수_할부_무이자_R3M] 분포
# 이용개월수_할부_무이자_R3M
# 0    2492195
# 1     272648
# 2     137214
# 3      97943
# Name: count, dtype: int64
#
# ▶ [이용개월수_CA_R3M] 분포
# 이용개월수_CA_R3M
# 0    2815226
# 3      84217
# 1      57067
# 2      43490
# Name: count, dtype: int64
#
# ▶ [이용개월수_체크_R3M] 분포
# 이용개월수_체크_R3M
# 0    2558688
# 3     345579
# 1      54029
# 2      41704
# Name: count, dtype: int64
#
# ▶ [이용개월수_카드론_R3M] 분포
# 이용개월수_카드론_R3M
# 0    2988136
# 1      11864
# Name: count, dtype: int64
#
# ▶ [이용가맹점수] 분포
# 이용가맹점수
# 0      732030
# 1      194565
# 2      153086
# 3      119223
# 4       94269
#         ...
# 104       381
# 105       181
# 106        70
# 107        14
# 108         2
# Name: count, Length: 109, dtype: int64
#
# ▶ [이용금액_해외] 분포
# 이용금액_해외
# 0       2682943
# 1208        436
# 1307        436
# 1248        432
# 1274        432
#          ...
# 5307          1
# 4817          1
# 4396          1
# 5458          1
# 406           1
# Name: count, Length: 4452, dtype: int64
#
# ▶ [쇼핑_도소매_이용금액] 분포
# 쇼핑_도소매_이용금액
# 0       1652904
# 767        1738
# 720        1732
# 765        1722
# 795        1718
#          ...
# 7891          1
# 5412          1
# 7373          1
# 6387          1
# 7646          1
# Name: count, Length: 6526, dtype: int64
#
# ▶ [쇼핑_백화점_이용금액] 분포
# 쇼핑_백화점_이용금액
# 0       2544619
# 690        1563
# 683        1561
# 673        1553
# 679        1541
#          ...
# 1709          1
# 1717          1
# 1734          1
# 357           1
# 2076          1
# Name: count, Length: 1547, dtype: int64
#
# ▶ [쇼핑_마트_이용금액] 분포
# 쇼핑_마트_이용금액
# 0       2024723
# 865        1623
# 856        1619
# 873        1619
# 844        1619
#          ...
# 4155          1
# 3593          1
# 4704          1
# 4785          1
# 4907          1
# Name: count, Length: 4227, dtype: int64
#
# ▶ [쇼핑_슈퍼마켓_이용금액] 분포
# 쇼핑_슈퍼마켓_이용금액
# 0       1637204
# 498        2211
# 476        2206
# 487        2147
# 495        2145
#          ...
# 4126          1
# 4825          1
# 3552          1
# 4280          1
# 3869          1
# Name: count, Length: 4125, dtype: int64
#
# ▶ [쇼핑_편의점_이용금액] 분포
# 쇼핑_편의점_이용금액
# 0       1788685
# 200        4216
# 213        4209
# 212        4206
# 202        4201
#          ...
# 4983          1
# 4768          1
# 5042          1
# 3832          1
# 3589          1
# Name: count, Length: 4454, dtype: int64
#
# ▶ [쇼핑_아울렛_이용금액] 분포
# 쇼핑_아울렛_이용금액
# 0       2751278
# 505        1512
# 511        1504
# 494        1498
# 513        1495
#          ...
# 1015          1
# 313           1
# 991           1
# 1079          1
# 959           1
# Name: count, Length: 737, dtype: int64
#
# ▶ [쇼핑_온라인_이용금액] 분포
# 쇼핑_온라인_이용금액
# 0        1893688
# 490          562
# 540          552
# 609          541
# 573          538
#           ...
# 37979          1
# 35754          1
# 59928          1
# 41567          1
# 27629          1
# Name: count, Length: 37430, dtype: int64
#
# ▶ [쇼핑_기타_이용금액] 분포
# 쇼핑_기타_이용금액
# 0      2171178
# 280       4328
# 269       4308
# 276       4280
# 275       4269
#         ...
# 913          1
# 810          1
# 761          1
# 899          1
# 839          1
# Name: count, Length: 815, dtype: int64
#
# ▶ [교통_주유이용금액] 분포
# 교통_주유이용금액
# 0       2100754
# 1560        825
# 1578        821
# 1576        821
# 1555        820
#          ...
# 7062          1
# 7083          1
# 9370          1
# 7788          1
# 7038          1
# Name: count, Length: 7762, dtype: int64
#
# ▶ [교통_정비이용금액] 분포
# 교통_정비이용금액
# 0       2341773
# 362        2300
# 377        2299
# 360        2292
# 383        2282
#          ...
# 1394          1
# 1186          1
# 137           1
# 1351          1
# 1434          1
# Name: count, Length: 1367, dtype: int64
#
# ▶ [교통_버스지하철이용금액] 분포
# 교통_버스지하철이용금액
# 0       2328968
# 239         775
# 234         772
# 276         771
# 252         770
#          ...
# 2116          1
# 2055          1
# 2057          1
# 2107          1
# 2037          1
# Name: count, Length: 2077, dtype: int64
#
# ▶ [교통_택시이용금액] 분포
# 교통_택시이용금액
# 0      2366691
# 215       5078
# 222       5063
# 217       5062
# 221       5058
#         ...
# 831          1
# 834          1
# 98           1
# 80           1
# 860          1
# Name: count, Length: 757, dtype: int64
#
# ▶ [교통_철도버스이용금액] 분포
# 교통_철도버스이용금액
# 0       2735230
# 458        2175
# 453        2122
# 451        2118
# 456        2111
#          ...
# 884           1
# 810           1
# 1019          1
# 1029          1
# 844           1
# Name: count, Length: 644, dtype: int64
#
# ▶ [여유_운동이용금액] 분포
# 여유_운동이용금액
# 0       2671623
# 895         815
# 912         807
# 924         803
# 932         799
#          ...
# 439           1
# 2350          1
# 2461          1
# 2407          1
# 2568          1
# Name: count, Length: 2058, dtype: int64
#
# ▶ [여유_Pet이용금액] 분포
# 여유_Pet이용금액
# 0      2960269
# 489        612
# 486        610
# 490        602
# 481        596
#         ...
# 827          1
# 833          1
# 773          1
# 691          1
# 721          1
# Name: count, Length: 368, dtype: int64
#
# ▶ [여유_공연이용금액] 분포
# 여유_공연이용금액
# 0      2835390
# 208       4852
# 207       4803
# 206       4786
# 205       4768
#         ...
# 354          1
# 287          1
# 122          1
# 123          1
# 301          1
# Name: count, Length: 186, dtype: int64
#
# ▶ [여유_공원이용금액] 분포
# 여유_공원이용금액
# 0      2993833
# 224        255
# 220        254
# 225        235
# 221        232
#         ...
# 298          1
# 343          1
# 325          1
# 311          1
# 307          1
# Name: count, Length: 140, dtype: int64
#
# ▶ [여유_숙박이용금액] 분포
# 여유_숙박이용금액
# 0       2975935
# 637         149
# 651         148
# 625         141
# 661         140
#          ...
# 456           1
# 1026          1
# 963           1
# 473           1
# 948           1
# Name: count, Length: 528, dtype: int64
#
# ▶ [여유_항공이용금액] 분포
# 여유_항공이용금액
# 0       2993705
# 2819         19
# 2944         18
# 2882         17
# 2705         17
#          ...
# 2188          1
# 2466          1
# 3882          1
# 3272          1
# 3967          1
# Name: count, Length: 1334, dtype: int64
#
# ▶ [여유_기타이용금액] 분포
# 여유_기타이용금액
# 0      2898932
# 218       1984
# 214       1948
# 223       1944
# 219       1938
#         ...
# 363          1
# 140          1
# 139          1
# 136          1
# 122          1
# Name: count, Length: 256, dtype: int64
#
# ▶ [납부_통신비이용금액] 분포
# 납부_통신비이용금액
# 0       2104622
# 1327        695
# 1463        665
# 1434        663
# 1487        659
#          ...
# 6754          1
# 6509          1
# 6044          1
# 6012          1
# 6941          1
# Name: count, Length: 6198, dtype: int64
#
# ▶ [납부_관리비이용금액] 분포
# 납부_관리비이용금액
# 0       2908388
# 4714        337
# 4724        332
# 4760        330
# 4687        330
#          ...
# 5176          1
# 4182          1
# 4276          1
# 4145          1
# 5199          1
# Name: count, Length: 1096, dtype: int64
#
# ▶ [납부_가스전기료이용금액] 분포
# 납부_가스전기료이용금액
# 0      2938205
# 607        565
# 601        546
# 589        539
# 594        539
#         ...
# 952          1
# 890          1
# 862          1
# 889          1
# 907          1
# Name: count, Length: 475, dtype: int64
#
# ▶ [납부_보험료이용금액] 분포
# 납부_보험료이용금액
# 0       2691659
# 2034        503
# 2084        503
# 2040        501
# 2015        498
#          ...
# 3510          1
# 3554          1
# 3661          1
# 3565          1
# 3705          1
# Name: count, Length: 2680, dtype: int64
#
# ▶ [납부_기타이용금액] 분포
# 납부_기타이용금액
# 0       2293750
# 24        10217
# 23        10032
# 25         9693
# 22         9344
#          ...
# 1076          1
# 902           1
# 1008          1
# 1270          1
# 1095          1
# Name: count, Length: 1151, dtype: int64
#
# ▶ [_1순위업종] 분포
# _1순위업종
# 쇼핑      1287610
# None     676567
# 납부       513768
# 교통       239549
# 사교활동     125140
# 교육        95561
# 해외        33211
# 의료        25224
# 여유생활       2985
# 일상생활        377
# 요식            8
# Name: count, dtype: int64
#
# ▶ [_1순위업종_이용금액] 분포
# _1순위업종_이용금액
# 0        676576
# 24         9068
# 23         9050
# 22         8443
# 25         8433
#           ...
# 78191         1
# 71355         1
# 57608         1
# 54934         1
# 64203         1
# Name: count, Length: 62881, dtype: int64
#
# ▶ [_2순위업종] 분포
# _2순위업종
# None    1143812
# 사교활동     630081
# 쇼핑       388100
# 납부       330912
# 교통       318668
# 의료        85471
# 교육        48153
# 해외        39945
# 여유생활      11528
# 일상생활       3163
# 요식          167
# Name: count, dtype: int64
#
# ▶ [_2순위업종_이용금액] 분포
# _2순위업종_이용금액
# 0        1143824
# 1729         929
# 1718         921
# 1739         912
# 1717         910
#           ...
# 23952          1
# 23314          1
# 22943          1
# 21814          1
# 16097          1
# Name: count, Length: 23123, dtype: int64
#
# ▶ [_3순위업종] 분포
# _3순위업종
# None    1387704
# 사교활동     521039
# 교통       476027
# 납부       205854
# 쇼핑       149058
# 의료       126064
# 해외        47066
# 여유생활      34746
# 일상생활      21519
# 요식        18179
# 교육        12744
# Name: count, dtype: int64
#
# ▶ [_3순위업종_이용금액] 분포
# _3순위업종_이용금액
# 0        1387715
# 903         1588
# 904         1544
# 901         1542
# 902         1524
#           ...
# 13054          1
# 20014          1
# 16666          1
# 17377          1
# 12185          1
# Name: count, Length: 13627, dtype: int64
#
# ▶ [_1순위쇼핑업종] 분포
# _1순위쇼핑업종
# None    1155434
# 온라인      826841
# 도소매      515619
# 마트       274049
# 슈퍼마켓     130420
# 편의점       61079
# 백화점       22907
# 쇼핑기타      10722
# 아울렛        2929
# Name: count, dtype: int64
#
# ▶ [_1순위쇼핑업종_이용금액] 분포
# _1순위쇼핑업종_이용금액
# 0        1155434
# 874         1539
# 888         1538
# 837         1526
# 881         1526
#           ...
# 23101          1
# 41761          1
# 39245          1
# 28323          1
# 27629          1
# Name: count, Length: 37430, dtype: int64
#
# ▶ [_2순위쇼핑업종] 분포
# _2순위쇼핑업종
# None    1421400
# 도소매      473600
# 마트       417445
# 슈퍼마켓     351199
# 편의점      135475
# 온라인       90878
# 백화점       67914
# 쇼핑기타      33018
# 아울렛        9071
# Name: count, dtype: int64
#
# ▶ [_2순위쇼핑업종_이용금액] 분포
# _2순위쇼핑업종_이용금액
# 0       1421400
# 770        1950
# 762        1937
# 717        1933
# 724        1930
#          ...
# 6133          1
# 7654          1
# 5237          1
# 5064          1
# 5583          1
# Name: count, Length: 5788, dtype: int64
#
# ▶ [_3순위쇼핑업종] 분포
# _3순위쇼핑업종
# None    1643222
# 슈퍼마켓     427283
# 도소매      256352
# 마트       210356
# 편의점      192004
# 백화점      106563
# 쇼핑기타      77089
# 온라인       63861
# 아울렛       23270
# Name: count, dtype: int64
#
# ▶ [_3순위쇼핑업종_이용금액] 분포
# _3순위쇼핑업종_이용금액
# 0       1643222
# 658        1786
# 695        1780
# 673        1764
# 656        1759
#          ...
# 4160          1
# 3591          1
# 5474          1
# 4072          1
# 3445          1
# Name: count, Length: 4039, dtype: int64
#
# ▶ [_1순위교통업종] 분포
# _1순위교통업종
# None     1457454
# 주유        890179
# 버스지하철     336559
# 정비        148132
# 택시        104764
# 철도버스       62912
# Name: count, dtype: int64
#
# ▶ [_1순위교통업종_이용금액] 분포
# _1순위교통업종_이용금액
# 0       1457518
# 229        1517
# 220        1476
# 215        1468
# 221        1467
#          ...
# 7889          1
# 8021          1
# 8121          1
# 9527          1
# 7038          1
# Name: count, Length: 8448, dtype: int64
#
# ▶ [_2순위교통업종] 분포
# _2순위교통업종
# None     2071153
# 정비        359728
# 버스지하철     219552
# 택시        211456
# 철도버스      129026
# 주유          9067
# 통행료           18
# Name: count, dtype: int64
#
# ▶ [_2순위교통업종_이용금액] 분포
# _2순위교통업종_이용금액
# 0       2071222
# 444        2454
# 439        2454
# 450        2440
# 453        2407
#          ...
# 1933          1
# 2193          1
# 1876          1
# 1870          1
# 1967          1
# Name: count, Length: 1919, dtype: int64
#
# ▶ [_3순위교통업종] 분포
# _3순위교통업종
# None     2556184
# 택시        192026
# 정비        113681
# 버스지하철      76289
# 철도버스       61801
# 통행료           19
# Name: count, dtype: int64
#
# ▶ [_3순위교통업종_이용금액] 분포
# _3순위교통업종_이용금액
# 0       2556260
# 222        1718
# 215        1708
# 217        1697
# 225        1682
#          ...
# 994           1
# 1053          1
# 966           1
# 1006          1
# 961           1
# Name: count, Length: 1035, dtype: int64
#
# ▶ [_1순위여유업종] 분포
# _1순위여유업종
# None    2485573
# 운동       325685
# 공연        91220
# 여유기타      53528
# Pet       25447
# 숙박        10874
# 항공         6294
# 공원         1379
# Name: count, dtype: int64
#
# ▶ [_1순위여유업종_이용금액] 분포
# _1순위여유업종_이용금액
# 0       2485573
# 208        3735
# 209        3716
# 207        3684
# 206        3621
#          ...
# 3621          1
# 3735          1
# 3980          1
# 3422          1
# 3967          1
# Name: count, Length: 3433, dtype: int64
#
# ▶ [_2순위여유업종] 분포
# _2순위여유업종
# None    2878107
# 공연        54759
# 여유기타      37026
# Pet       13091
# 숙박        11985
# 운동         2690
# 공원         2341
# 항공            1
# Name: count, dtype: int64
#
# ▶ [_2순위여유업종_이용금액] 분포
# _2순위여유업종_이용금액
# 0       2878107
# 208        2154
# 207        2154
# 206        2089
# 205        2082
#          ...
# 1190          1
# 1293          1
# 1281          1
# 1936          1
# 1613          1
# Name: count, Length: 1739, dtype: int64
#
# ▶ [_3순위여유업종] 분포
# _3순위여유업종
# None    2972290
# 공연        14852
# 여유기타       8902
# 공원         1656
# 숙박         1206
# Pet        1092
# 운동            2
# Name: count, dtype: int64
#
# ▶ [_3순위여유업종_이용금액] 분포
# _3순위여유업종_이용금액
# 0      2972290
# 207        571
# 205        559
# 204        549
# 209        542
#         ...
# 886          1
# 917          1
# 136          1
# 405          1
# 122          1
# Name: count, Length: 688, dtype: int64
#
# ▶ [_1순위납부업종] 분포
# _1순위납부업종
# None      1522257
# 통신비        748346
# 납부기타       403870
# 보험료        223673
# 관리비         90708
# 가스/전기료      11146
# Name: count, dtype: int64
#
# ▶ [_1순위납부업종_이용금액] 분포
# _1순위납부업종_이용금액
# 0       1522257
# 24        10056
# 23         9914
# 25         9504
# 22         9242
#          ...
# 6343          1
# 6228          1
# 6280          1
# 6211          1
# 6941          1
# Name: count, Length: 6692, dtype: int64
#
# ▶ [_2순위납부업종] 분포
# _2순위납부업종
# None      2543911
# 납부기타       211159
# 통신비        138595
# 보험료         77101
# 가스/전기료      28330
# 관리비           904
# Name: count, dtype: int64
#
# ▶ [_2순위납부업종_이용금액] 분포
# _2순위납부업종_이용금액
# 0       2543911
# 51         1361
# 46         1338
# 48         1322
# 53         1314
#          ...
# 4103          1
# 4694          1
# 4972          1
# 4363          1
# 4383          1
# Name: count, Length: 4893, dtype: int64
#
# ▶ [_3순위납부업종] 분포
# _3순위납부업종
# None      2888898
# 납부기타        76221
# 가스/전기료      18877
# 통신비          8438
# 보험료          7566
# Name: count, dtype: int64
#
# ▶ [_3순위납부업종_이용금액] 분포
# _3순위납부업종_이용금액
# 0       2888898
# 207         322
# 241         320
# 210         318
# 215         318
#          ...
# 2821          1
# 2881          1
# 3333          1
# 2743          1
# 2804          1
# Name: count, Length: 2839, dtype: int64
#
# ▶ [할부건수_3M_R12M] 분포
# 할부건수_3M_R12M
# 0     2203288
# 4      227752
# 3       96586
# 5       73943
# 8       55574
# 7       43020
# 9       42418
# 6       40338
# 10      31135
# 11      25342
# 12      21349
# 13      17934
# 14      15169
# 15      13033
# 16      11218
# 17       9677
# 18       8524
# 19       7353
# 20       6492
# 21       6010
# 22       5388
# 23       5044
# 24       4446
# 25       4246
# 26       3774
# 27       3339
# 28       2937
# 29       2637
# 30       2219
# 31       1876
# 32       1608
# 33       1257
# 34       1037
# 35        831
# 2         761
# 36        624
# 37        491
# 38        388
# 39        303
# 40        219
# 41        137
# 42        102
# 43         56
# 44         36
# 45         24
# 46         18
# 47         15
# 48         11
# 49          9
# 51          4
# 50          3
# 55          2
# 52          1
# 53          1
# 54          1
# Name: count, dtype: int64
#
# ▶ [할부건수_6M_R12M] 분포
# 할부건수_6M_R12M
# 0     2539386
# 4      205868
# 3       85087
# 5       53992
# 8       26355
# 7       23777
# 6       23339
# 9       17335
# 10      10159
# 11       5945
# 12       3642
# 13       2382
# 14       1380
# 15        766
# 16        348
# 17        162
# 18         48
# 19         23
# 20          3
# 2           2
# 21          1
# Name: count, dtype: int64
#
# ▶ [할부건수_12M_R12M] 분포
# 할부건수_12M_R12M
# 0     2971616
# 3       17183
# 4       10640
# 7         477
# 6          62
# 10         19
# 5           2
# 8           1
# Name: count, dtype: int64
#
# ▶ [할부금액_3M_R12M] 분포
# 할부금액_3M_R12M
# 0        1890358
# 1961         196
# 1978         189
# 2004         187
# 2112         187
#           ...
# 63637          1
# 42192          1
# 42232          1
# 66875          1
# 61857          1
# Name: count, Length: 64059, dtype: int64
#
# ▶ [할부금액_6M_R12M] 분포
# 할부금액_6M_R12M
# 0        2220746
# 4205         135
# 4140         135
# 6192         131
# 4034         129
#           ...
# 39671          1
# 33662          1
# 28618          1
# 35997          1
# 42162          1
# Name: count, Length: 33420, dtype: int64
#
# ▶ [할부금액_12M_R12M] 분포
# 할부금액_12M_R12M
# 0        2789696
# 3604         180
# 3600         174
# 3456         173
# 3474         169
#           ...
# 16830          1
# 14852          1
# 2879           1
# 5133           1
# 16596          1
# Name: count, Length: 17546, dtype: int64
#
# ▶ [할부금액_14M_R12M] 분포
# 할부금액_14M_R12M
# 0        2906810
# 3567         975
# 3568         965
# 3569         899
# 3570         729
#           ...
# 20055          1
# 31041          1
# 30045          1
# 30422          1
# 31434          1
# Name: count, Length: 3004, dtype: int64
#
# ▶ [할부건수_유이자_3M_R12M] 분포
# 할부건수_유이자_3M_R12M
# 0     2713419
# 4      133460
# 5       44274
# 3       36984
# 6       24073
# 7       17199
# 8       13071
# 9        8763
# 10       4749
# 11       2282
# 12        947
# 13        464
# 14        185
# 15         74
# 16         34
# 17         14
# 2           6
# 18          2
# Name: count, dtype: int64
#
# ▶ [할부건수_유이자_6M_R12M] 분포
# 할부건수_유이자_6M_R12M
# 0    2914777
# 4      51181
# 3      30010
# 5       4012
# 6         20
# Name: count, dtype: int64
#
# ▶ [할부건수_유이자_12M_R12M] 분포
# 할부건수_유이자_12M_R12M
# 0    2987172
# 4      11056
# 3       1771
# 5          1
# Name: count, dtype: int64
#
# ▶ [할부금액_유이자_3M_R12M] 분포
# 할부금액_유이자_3M_R12M
# 0        2556459
# 5761         118
# 5695         112
# 5449         111
# 5098         111
#           ...
# 20931          1
# 23253          1
# 688            1
# 23768          1
# 23704          1
# Name: count, Length: 21187, dtype: int64
#
# ▶ [할부금액_유이자_6M_R12M] 분포
# 할부금액_유이자_6M_R12M
# 0        2796210
# 6191         114
# 6372         111
# 6386         111
# 6265         111
#           ...
# 10739          1
# 11059          1
# 12832          1
# 14226          1
# 12046          1
# Name: count, Length: 8221, dtype: int64
#
# ▶ [할부금액_유이자_12M_R12M] 분포
# 할부금액_유이자_12M_R12M
# 0        2940935
# 10606         40
# 10993         40
# 11188         37
# 11033         37
#           ...
# 14153          1
# 14287          1
# 15569          1
# 8672           1
# 14779          1
# Name: count, Length: 6470, dtype: int64
#
# ▶ [할부금액_유이자_14M_R12M] 분포
# 할부금액_유이자_14M_R12M
# 0       2916482
# 4132        218
# 4088        211
# 4130        209
# 4174        205
#          ...
# 5694          1
# 5414          1
# 5241          1
# 5329          1
# 5420          1
# Name: count, Length: 2056, dtype: int64
#
# ▶ [할부건수_무이자_3M_R12M] 분포
# 할부건수_무이자_3M_R12M
# 0     2262645
# 4      245589
# 5      103143
# 3       99162
# 6       57641
# 7       42804
# 8       33143
# 9       25613
# 10      19159
# 11      14830
# 12      11661
# 13       9201
# 14       8037
# 15       6942
# 16       6418
# 17       5810
# 18       5437
# 19       5105
# 20       4611
# 21       4406
# 22       3947
# 23       3680
# 24       3276
# 25       3043
# 26       2637
# 27       2197
# 28       1845
# 29       1546
# 30       1304
# 31       1028
# 2         913
# 32        846
# 33        621
# 34        489
# 35        375
# 36        253
# 37        199
# 38        144
# 39        103
# 40         80
# 41         38
# 42         31
# 43         15
# 44         11
# 45          8
# 46          7
# 47          4
# 48          2
# 49          1
# Name: count, dtype: int64
#
# ▶ [할부건수_무이자_6M_R12M] 분포
# 할부건수_무이자_6M_R12M
# 0     2572611
# 4      207794
# 3       74587
# 5       63884
# 6       27345
# 7       18215
# 8       14279
# 9       10503
# 10       6240
# 11       2959
# 12       1106
# 13        344
# 14         98
# 15         28
# 16          5
# 2           2
# Name: count, dtype: int64
#
# ▶ [할부건수_무이자_12M_R12M] 분포
# 할부건수_무이자_12M_R12M
# 0    2984313
# 3      15606
# 4         81
# Name: count, dtype: int64
#
# ▶ [할부금액_무이자_3M_R12M] 분포
# 할부금액_무이자_3M_R12M
# 0        1972807
# 1961         240
# 1899         239
# 2207         235
# 1967         232
#           ...
# 39668          1
# 39380          1
# 90004          1
# 89192          1
# 94326          1
# Name: count, Length: 58211, dtype: int64
#
# ▶ [할부금액_무이자_6M_R12M] 분포
# 할부금액_무이자_6M_R12M
# 0        2291351
# 4140         154
# 4205         153
# 4682         150
# 4320         146
#           ...
# 31710          1
# 31880          1
# 19351          1
# 32401          1
# 33331          1
# Name: count, Length: 30463, dtype: int64
#
# ▶ [할부금액_무이자_12M_R12M] 분포
# 할부금액_무이자_12M_R12M
# 0       2880621
# 3604        197
# 3497        196
# 3600        192
# 3579        191
#          ...
# 2648          1
# 4841          1
# 2579          1
# 5094          1
# 4839          1
# Name: count, Length: 2387, dtype: int64
#
# ▶ [할부금액_무이자_14M_R12M] 분포
# 할부금액_무이자_14M_R12M
# 0        2990379
# 3567         980
# 3568         964
# 3569         900
# 3570         730
#           ...
# 30893          1
# 30867          1
# 30552          1
# 30490          1
# 31434          1
# Name: count, Length: 828, dtype: int64
#
# ▶ [할부금액_부분_12M_R12M] 분포
# 할부금액_부분_12M_R12M
# 0        2940494
# 7976          75
# 7815          68
# 7820          66
# 7938          65
#           ...
# 6069           1
# 6258           1
# 10890          1
# 9283           1
# 5881           1
# Name: count, Length: 3488, dtype: int64
#
# ▶ [RP건수_B0M] 분포
# RP건수_B0M
# 0    1590925
# 1     750490
# 2     376634
# 3     175819
# 4      79467
# 5      23535
# 6       2979
# 7        146
# 8          5
# Name: count, dtype: int64
#
# ▶ [RP금액_B0M] 분포
# RP금액_B0M
# 0        1593738
# 8          22942
# 7          21759
# 9          19459
# 6          16372
#           ...
# 14504          1
# 17660          1
# 12208          1
# 9220           1
# 14622          1
# Name: count, Length: 11915, dtype: int64
#
# ▶ [RP유형건수_B0M] 분포
# RP유형건수_B0M
# 0    1634623
# 1     905365
# 2     326086
# 3     133896
# 4         30
# Name: count, dtype: int64
#
# ▶ [RP건수_통신_B0M] 분포
# RP건수_통신_B0M
# 0    2230233
# 1     554821
# 2     214945
# 3          1
# Name: count, dtype: int64
#
# ▶ [RP건수_아파트_B0M] 분포
# RP건수_아파트_B0M
# 0    2905806
# 1      94194
# Name: count, dtype: int64
#
# ▶ [RP건수_제휴사서비스직접판매_B0M] 분포
# RP건수_제휴사서비스직접판매_B0M
# 0    2679531
# 1     320469
# Name: count, dtype: int64
#
# ▶ [RP건수_렌탈_B0M] 분포
# RP건수_렌탈_B0M
# ...
# 2       84532
# 12      83620
# 3       66217
# 10      61508
# 4       59069
# 6       58450
# 1       58037
# 9       57709
# 5       54890
# 11      54394
# 8       51273
# 7       47680
# 13      29946
# 18      28654
# 17      23812
# 14      23448
# 15      20980
# 16      20688
# 19      17537
# 20      12997
# 24      12112
# 21      11021
# 23       9806
# 22       9689
# 25       5394
# 26       1758
# 27        511
# 28        139
# 29         93
# 30          9
# Name: count, dtype: int64
#
# ▶ [이용건수_A페이_R6M] 분포
# 이용건수_A페이_R6M
# 0     2773806
# 6       59389
# 5       26220
# 4       25812
# 8       23822
# 3       23394
# 7       18785
# 10      13125
# 9       12138
# 2       10179
# 11       9377
# 12       2277
# 1        1495
# 13        177
# 14          4
# Name: count, dtype: int64
#
# ▶ [이용건수_B페이_R6M] 분포
# 이용건수_B페이_R6M
# 0    2926095
# 1      46144
# 6       7357
# 2       7141
# 3       4808
# 5       4386
# 4       4069
# Name: count, dtype: int64
#
# ▶ [이용건수_C페이_R6M] 분포
# 이용건수_C페이_R6M
# 0    2927892
# 1      41477
# 2       9446
# 4       9191
# 3       6030
# 5       3198
# 6       2766
# Name: count, dtype: int64
#
# ▶ [이용건수_D페이_R6M] 분포
# 이용건수_D페이_R6M
# 0    2920458
# 1      73242
# 2       3094
# 3       1640
# 4       1133
# 5        246
# 6        187
# Name: count, dtype: int64
#
# ▶ [이용금액_간편결제_R3M] 분포
# 이용금액_간편결제_R3M
# 0        2158030
# 2826         200
# 3085         198
# 2608         197
# 3055         197
#           ...
# 25862          1
# 41612          1
# 41490          1
# 38425          1
# 67521          1
# Name: count, Length: 38270, dtype: int64
#
# ▶ [이용금액_A페이_R3M] 분포
# 이용금액_A페이_R3M
# 0        2793992
# 2707          81
# 2651          80
# 2759          79
# 2641          78
#           ...
# 19812          1
# 17464          1
# 15865          1
# 17303          1
# 13999          1
# Name: count, Length: 17069, dtype: int64
#
# ▶ [이용금액_B페이_R3M] 분포
# 이용금액_B페이_R3M
# 0       2937519
# 678         180
# 670         172
# 677         171
# 667         170
#          ...
# 1581          1
# 1544          1
# 880           1
# 1619          1
# 2432          1
# Name: count, Length: 1549, dtype: int64
#
# ▶ [이용금액_C페이_R3M] 분포
# 이용금액_C페이_R3M
# 0       2935527
# 461         142
# 465         138
# 479         136
# 447         136
#          ...
# 302           1
# 1949          1
# 335           1
# 293           1
# 1997          1
# Name: count, Length: 1615, dtype: int64
#
# ▶ [이용금액_D페이_R3M] 분포
# 이용금액_D페이_R3M
# 0      2956936
# 463        367
# 456        366
# 454        366
# 458        365
#         ...
# 973          1
# 202          1
# 171          1
# 993          1
# 769          1
# Name: count, Length: 746, dtype: int64
#
# ▶ [이용건수_간편결제_R3M] 분포
# 이용건수_간편결제_R3M
# 0     2158216
# 6      268159
# 3      102850
# 4       84479
# 2       81438
# 9       73634
# 5       65903
# 7       35688
# 1       31399
# 8       30673
# 12      29082
# 10      18623
# 11      14955
# 13       3723
# 14        962
# 15        216
# Name: count, dtype: int64
#
# ▶ [이용건수_A페이_R3M] 분포
# 이용건수_A페이_R3M
# 0    2798597
# 3     145919
# 2      18549
# 5      17106
# 4      12078
# 1       5261
# 6       2487
# 7          3
# Name: count, dtype: int64
#
# ▶ [이용건수_B페이_R3M] 분포
# 이용건수_B페이_R3M
# 0    2942047
# 3      23979
# 1      21684
# 2      12290
# Name: count, dtype: int64
#
# ▶ [이용건수_C페이_R3M] 분포
# 이용건수_C페이_R3M
# 0    2935900
# 1      31003
# 3      20070
# 2      13027
# Name: count, dtype: int64
#
# ▶ [이용건수_D페이_R3M] 분포
# 이용건수_D페이_R3M
# 0    2966911
# 1      28587
# 2       2631
# 3       1871
# Name: count, dtype: int64
#
# ▶ [이용금액_간편결제_B0M] 분포
# 이용금액_간편결제_B0M
# 0        2232533
# 962          681
# 997          678
# 1011         666
# 1020         665
#           ...
# 11498          1
# 16474          1
# 21805          1
# 13768          1
# 9911           1
# Name: count, Length: 13871, dtype: int64
#
# ▶ [이용금액_A페이_B0M] 분포
# 이용금액_A페이_B0M
# 0       2807645
# 952         275
# 968         272
# 957         271
# 894         266
#          ...
# 6202          1
# 7182          1
# 5064          1
# 4954          1
# 546           1
# Name: count, Length: 4597, dtype: int64
#
# ▶ [이용금액_B페이_B0M] 분포
# 이용금액_B페이_B0M
# 0      2959712
# 679        598
# 678        596
# 683        585
# 685        584
#         ...
# 872          1
# 881          1
# 942          1
# 850          1
# 873          1
# Name: count, Length: 375, dtype: int64
#
# ▶ [이용금액_C페이_B0M] 분포
# 이용금액_C페이_B0M
# 0      2950410
# 469        460
# 471        454
# 465        453
# 462        449
#         ...
# 923          1
# 308          1
# 292          1
# 801          1
# 956          1
# Name: count, Length: 535, dtype: int64
#
# ▶ [이용금액_D페이_B0M] 분포
# 이용금액_D페이_B0M
# 0      2990122
# 294        323
# 290        322
# 292        300
# 289        300
#         ...
# 372          1
# 374          1
# 370          1
# 366          1
# 401          1
# Name: count, Length: 204, dtype: int64
#
# ▶ [이용건수_간편결제_B0M] 분포
# 이용건수_간편결제_B0M
# 0    2232585
# 2     472150
# 3     130219
# 1     114249
# 4      49655
# 5       1142
# Name: count, dtype: int64
#
# ▶ [이용건수_A페이_B0M] 분포
# 이용건수_A페이_B0M
# 0    2816046
# 1     183954
# Name: count, dtype: int64
#
# ▶ [이용건수_B페이_B0M] 분포
# 이용건수_B페이_B0M
# 0    2959216
# 1      40784
# Name: count, dtype: int64
#
# ▶ [이용건수_C페이_B0M] 분포
# 이용건수_C페이_B0M
# 0    2949853
# 1      50147
# Name: count, dtype: int64
#
# ▶ [이용건수_D페이_B0M] 분포
# 이용건수_D페이_B0M
# 0    2991075
# 1       8925
# Name: count, dtype: int64
#
# ▶ [이용개월수_선결제_R6M] 분포
# 이용개월수_선결제_R6M
# 0    2739199
# 1     130866
# 6      76942
# 3      21756
# 2      14158
# 4      14144
# 5       2935
# Name: count, dtype: int64
#
# ▶ [이용횟수_선결제_R6M] 분포
# 이용횟수_선결제_R6M
# 0     2730413
# 2       70984
# 3       31604
# 1       25574
# 4       20989
# 12      19906
# 9       17045
# 10      15613
# 5       13812
# 6       13645
# 8       13455
# 11      11741
# 7       11555
# 13       3145
# 14        495
# 15         24
# Name: count, dtype: int64
#
# ▶ [이용금액_선결제_R6M] 분포
# 이용금액_선결제_R6M
# 0         2730184
# 5056           47
# 5260           47
# 5581           45
# 5590           44
#            ...
# 49874           1
# 111359          1
# 77798           1
# 70312           1
# 45248           1
# Name: count, Length: 58272, dtype: int64
#
# ▶ [이용건수_선결제_R6M] 분포
# 이용건수_선결제_R6M
# 0      2793305
# 7        27832
# 18       24043
# 11       18353
# 94        6014
#         ...
# 496          1
# 472          1
# 16           1
# 470          1
# 518          1
# Name: count, Length: 514, dtype: int64
#
# ▶ [이용횟수_선결제_R3M] 분포
# 이용횟수_선결제_R3M
# 0    2825646
# 6      67008
# 2      45453
# 3      21079
# 4      20223
# 5      13245
# 1       5761
# 7       1495
# 8         90
# Name: count, dtype: int64
#
# ▶ [이용금액_선결제_R3M] 분포
# 이용금액_선결제_R3M
# 0        2826984
# 4494          28
# 4580          28
# 4469          28
# 4625          26
#           ...
# 33322          1
# 37947          1
# 48312          1
# 50811          1
# 24731          1
# Name: count, Length: 26936, dtype: int64
#
# ▶ [이용건수_선결제_R3M] 분포
# 이용건수_선결제_R3M
# 0      2901874
# 11       18508
# 42        6321
# 23        3857
# 7         3812
#         ...
# 266          1
# 269          1
# 328          1
# 246          1
# 267          1
# Name: count, Length: 255, dtype: int64
#
# ▶ [이용횟수_선결제_B0M] 분포
# 이용횟수_선결제_B0M
# 0    2870902
# 2     116159
# 1      12913
# 3         26
# Name: count, dtype: int64
#
# ▶ [이용금액_선결제_B0M] 분포
# 이용금액_선결제_B0M
# 0       2872233
# 5281         73
# 5066         71
# 4940         69
# 4648         69
#          ...
# 8804          1
# 8487          1
# 9109          1
# 3424          1
# 3727          1
# Name: count, Length: 6373, dtype: int64
#
# ▶ [이용건수_선결제_B0M] 분포
# 이용건수_선결제_B0M
# 0      2954866
# 53       12197
# 7        11783
# 54        6102
# 38        3917
# 85        1539
# 84        1537
# 52        1479
# 37        1084
# 83         887
# 55         855
# 27         845
# 86         713
# 82         371
# 39         345
# 87         277
# 8          190
# 81         139
# 56         133
# 51         118
# 88         105
# 28         101
# 26          58
# 89          49
# 13          46
# 80          45
# 14          44
# 36          33
# 19          32
# 40          20
# 20          17
# 57          14
# 79          13
# 90          10
# 91           8
# 6            6
# 92           4
# 50           3
# 78           3
# 160          2
# 58           2
# 169          1
# 41           1
# 156          1
# 165          1
# 29           1
# 49           1
# 157          1
# 168          1
# Name: count, dtype: int64
#
# ▶ [이용횟수_연체_R6M] 분포
# 이용횟수_연체_R6M
# 0    2624877
# 1     155433
# 2      97425
# 3      56708
# 4      47710
# 5      13176
# 6       4671
# Name: count, dtype: int64
#
# ▶ [이용금액_연체_R6M] 분포
# 이용금액_연체_R6M
# 0        2635802
# 1450         176
# 1357         173
# 1564         172
# 1416         168
#           ...
# 31610          1
# 23885          1
# 50450          1
# 31635          1
# 15752          1
# Name: count, Length: 27312, dtype: int64
#
# ▶ [이용횟수_연체_R3M] 분포
# 이용횟수_연체_R3M
# 0    2844829
# 1      71462
# 2      60042
# 3      23667
# Name: count, dtype: int64
#
# ▶ [이용금액_연체_R3M] 분포
# 이용금액_연체_R3M
# 0        2835702
# 1735          78
# 1821          76
# 1460          75
# 1577          74
#           ...
# 11352          1
# 15872          1
# 9883           1
# 9053           1
# 8522           1
# Name: count, Length: 11012, dtype: int64
#
# ▶ [이용횟수_연체_B0M] 분포
# 이용횟수_연체_B0M
# 0    2948752
# 1      51248
# Name: count, dtype: int64
#
# ▶ [이용금액_연체_B0M] 분포
# 이용금액_연체_B0M
# 0       2931397
# 2015         89
# 2020         89
# 1989         88
# 1878         87
#          ...
# 3539          1
# 3625          1
# 4103          1
# 2945          1
# 3435          1
# Name: count, Length: 2664, dtype: int64
#
# ▶ [이용개월수_전체_R6M] 분포
# 이용개월수_전체_R6M
# 6    2004053
# 0     532488
# 5     124485
# 1     117109
# 4      90456
# 2      74935
# 3      56474
# Name: count, dtype: int64
#
# ▶ [이용개월수_전체_R3M] 분포
# 이용개월수_전체_R3M
# 3    2172633
# 0     654419
# 1      96937
# 2      76011
# Name: count, dtype: int64
#
# ▶ [이용개월수_결제일_R6M] 분포
# 이용개월수_결제일_R6M
# 6    1714258
# 0     616851
# 5     215563
# 4     131869
# 1     131468
# 2     113012
# 3      76979
# Name: count, dtype: int64
#
# ▶ [이용개월수_결제일_R3M] 분포
# 이용개월수_결제일_R3M
# 3    1959712
# 0     753229
# 2     154550
# 1     132509
# Name: count, dtype: int64
#
# ▶ [가맹점매출금액_B1M] 분포
# 가맹점매출금액_B1M
# 0        2820159
# 5820         188
# 5825         177
# 5834         176
# 5786         175
#           ...
# 7698           1
# 8881           1
# 10151          1
# 3872           1
# 8114           1
# Name: count, Length: 4928, dtype: int64
#
# ▶ [가맹점매출금액_B2M] 분포
# 가맹점매출금액_B2M
# 0        2819297
# 5820         186
# 5603         184
# 5688         183
# 5578         178
#           ...
# 7987           1
# 11487          1
# 9235           1
# 8163           1
# 7721           1
# Name: count, Length: 4664, dtype: int64
#
# ▶ [정상청구원금_B0M] 분포
# 정상청구원금_B0M
# 0        488242
# 17         2219
# 18         2201
# 16         2157
# 19         2043
#           ...
# 35171         1
# 41213         1
# 50956         1
# 39581         1
# 37083         1
# Name: count, Length: 39752, dtype: int64
#
# ▶ [선입금원금_B0M] 분포
# 선입금원금_B0M
# 0        2839130
# 5344          65
# 5476          59
# 5481          59
# 5147          58
#           ...
# 11424          1
# 13095          1
# 18443          1
# 16152          1
# 18660          1
# Name: count, Length: 11713, dtype: int64
#
# ▶ [정상입금원금_B0M] 분포
# 정상입금원금_B0M
# 0        839402
# 18         2766
# 17         2732
# 16         2643
# 19         2615
#           ...
# 41746         1
# 32262         1
# 53025         1
# 59763         1
# 30025         1
# Name: count, Length: 38485, dtype: int64
#
# ▶ [연체입금원금_B0M] 분포
# 연체입금원금_B0M
# 0        1559169
# 25           986
# 76           985
# 4            971
# 13           964
#           ...
# 19647          1
# 22208          1
# 23143          1
# 17276          1
# 21492          1
# Name: count, Length: 22095, dtype: int64
#
# ▶ [정상청구원금_B2M] 분포
# 정상청구원금_B2M
# 0        471205
# 17         1874
# 16         1844
# 15         1800
# 18         1741
#           ...
# 43956         1
# 56862         1
# 51301         1
# 68339         1
# 41682         1
# Name: count, Length: 42165, dtype: int64
#
# ▶ [선입금원금_B2M] 분포
# 선입금원금_B2M
# 0        2834792
# 5074          68
# 5358          66
# 5506          62
# 5229          61
#           ...
# 11233          1
# 17549          1
# 10701          1
# 2549           1
# 18926          1
# Name: count, Length: 11458, dtype: int64
#
# ▶ [정상입금원금_B2M] 분포
# 정상입금원금_B2M
# 0        855753
# 16         2171
# 17         2171
# 18         2101
# 15         2030
#           ...
# 40526         1
# 48979         1
# 38834         1
# 37503         1
# 30977         1
# Name: count, Length: 41141, dtype: int64
#
# ▶ [연체입금원금_B2M] 분포
# 연체입금원금_B2M
# 0        1466149
# 76           932
# 28           917
# 54           906
# 25           905
#           ...
# 20120          1
# 27613          1
# 21812          1
# 29076          1
# 24914          1
# Name: count, Length: 22924, dtype: int64
#
# ▶ [정상청구원금_B5M] 분포
# 정상청구원금_B5M
# 0        470217
# 24         1051
# 23         1038
# 22         1031
# 26          933
#           ...
# 58562         1
# 39394         1
# 69639         1
# 53353         1
# 32147         1
# Name: count, Length: 46729, dtype: int64
#
# ▶ [선입금원금_B5M] 분포
# 선입금원금_B5M
# 0        2835926
# 5638          70
# 5564          67
# 6084          66
# 5753          65
#           ...
# 12765          1
# 12628          1
# 20226          1
# 10657          1
# 14249          1
# Name: count, Length: 10443, dtype: int64
#
# ▶ [정상입금원금_B5M] 분포
# 정상입금원금_B5M
# 0        934951
# 24          972
# 23          942
# 22          933
# 25          869
#           ...
# 77401         1
# 41638         1
# 46741         1
# 34572         1
# 34685         1
# Name: count, Length: 45964, dtype: int64
#
# ▶ [연체입금원금_B5M] 분포
# 연체입금원금_B5M
# 0        1325273
# 37           720
# 9            706
# 16           703
# 203          701
#           ...
# 25736          1
# 26591          1
# 20551          1
# 20866          1
# 20507          1
# Name: count, Length: 23302, dtype: int64
#
# ▶ [건수_할부전환_R6M] 분포
# 건수_할부전환_R6M
# 0     2959651
# 6       18624
# 9        6967
# 10       4788
# 8        3906
# 5        3183
# 4        2208
# 7         667
# 11          6
# Name: count, dtype: int64
#
# ▶ [건수_할부전환_R3M] 분포
# 건수_할부전환_R3M
# 0    2963708
# 5      19291
# 4      16987
# 6         10
# 3          4
# Name: count, dtype: int64
#
# ▶ [금액_할부전환_R6M] 분포
# 금액_할부전환_R6M
# 0        2959634
# 6658          32
# 6587          28
# 6521          27
# 6495          25
#           ...
# 10572          1
# 7868           1
# 10748          1
# 10884          1
# 10933          1
# Name: count, Length: 6712, dtype: int64
#
# ▶ [금액_할부전환_R3M] 분포
# 금액_할부전환_R3M
# 0       2963629
# 4765         66
# 4808         66
# 4711         64
# 4737         64
#          ...
# 6586          1
# 6038          1
# 6045          1
# 3612          1
# 6356          1
# Name: count, Length: 2588, dtype: int64
#
# ▶ [연속무실적개월수_기본_24M_카드] 분포
# 연속무실적개월수_기본_24M_카드
# 0     2349762
# 5       69900
# 24      58356
# 8       57741
# 9       57031
# 12      49675
# 10      49625
# 4       48435
# 11      48008
# 13      47613
# 7       47611
# 6       45815
# 14      28961
# 3       20154
# 15       9946
# 2        8711
# 1        2146
# 16        505
# 17          5
# Name: count, dtype: int64
#
# ▶ [연속유실적개월수_기본_24M_카드] 분포
# 연속유실적개월수_기본_24M_카드
# 24    957019
# 0     759259
# 17    392172
# 8     343050
# 5     201981
# 12     59953
# 13     53467
# 2      46227
# 20     36922
# 21     33672
# 11     33476
# 9      29064
# 1      25294
# 4      23836
# 10      2508
# 18      1206
# 3        437
# 14       320
# 16        55
# 23        45
# 15        23
# 6         14
# Name: count, dtype: int64
#
# ▶ [신청건수_ATM_CA_B0] 분포
# 신청건수_ATM_CA_B0
# 0    2947247
# 3      43974
# 2       8625
# 4        154
# Name: count, dtype: int64
#
# ▶ [신청건수_ATM_CA_R6M] 분포
# 신청건수_ATM_CA_R6M
# 0     2843296
# 5       27658
# 4       25613
# 6       14863
# 7       10569
# 8        9711
# 9        9631
# 3        9165
# 10       8304
# 12       7831
# 11       7774
# 13       6552
# 14       5165
# 18       4545
# 2        4405
# 15       3620
# 16        887
# 17        287
# 19         97
# 20         14
# 1           8
# 21          5
# Name: count, dtype: int64
#
# ▶ [승인거절건수_B0M] 분포
# 승인거절건수_B0M
# 0    2996149
# 2       3803
# 3         46
# 5          2
# Name: count, dtype: int64
#
# ▶ [승인거절건수_한도초과_B0M] 분포
# 승인거절건수_한도초과_B0M
# 0    2996195
# 2       3805
# Name: count, dtype: int64
#
# ▶ [승인거절건수_R3M] 분포
# 승인거절건수_R3M
# 0     2891015
# 3       53263
# 2       39059
# 4        6758
# 5        5442
# 6        1877
# 7        1312
# 1         987
# 9         218
# 8          67
# 10          2
# Name: count, dtype: int64
#
# ▶ [승인거절건수_한도초과_R3M] 분포
# 승인거절건수_한도초과_R3M
# 0    2934304
# 3      60010
# 2       4343
# 4        879
# 6        464
# Name: count, dtype: int64
#
# ▶ [승인거절건수_BL_R3M] 분포
# 승인거절건수_BL_R3M
# 0    2990584
# 4       8251
# 3       1151
# 6          8
# 5          5
# 9          1
# Name: count, dtype: int64
#
# ▶ [승인거절건수_기타_R3M] 분포
# 승인거절건수_기타_R3M
# 0    2957152
# 2      41687
# 1       1161
# Name: count, dtype: int64
#
# ▶ [이용금액대] 분포
# 이용금액대
# 09.미사용       610887
# 05.10만원-     579313
# 02.50만원+     574778
# 01.100만원+    442685
# 04.10만원+     416275
# 03.30만원+     376062
# Name: count, dtype: int64
#
# ▶ [Segment] 분포
# Segment
# E       1922052
# None     600000
# D        349242
# C        127590
# A           972
# B           144
# Name: count, dtype: int64

# %%
# 이름에 '일자'가 들어가는 모든 컬럼 찾기
date_cols = [c for c in df.columns if '일자' in c]

# 각 일자 컬럼에 대해 _dt 컬럼 생성
for col in date_cols:
    # 문자열로 변환 후, '.0'이 있으면 제거
    s = df[col].astype(str).str.replace(r'\.0$', '', regex=True)
    # YYYYMMDD 포맷으로 파싱 (파싱 실패 시 NaT)
    df[f'{col}_dt'] = pd.to_datetime(s, format='%Y%m%d', errors='coerce')

# 원본 일자 컬럼 삭제
df.drop(columns=date_cols, inplace=True)

# %%
# 이용금액대 순서형 인코딩 → '_ord' 생성 & 원본 삭제
ord_levels_amt = [
    "09.미사용",
    "05.10만원-",
    "02.50만원+",
    "04.10만원+",
    "03.30만원+",
    "01.100만원+"
]
mapping_amt = {lvl: i+1 for i, lvl in enumerate(ord_levels_amt)}
df['이용금액대_ord'] = df['이용금액대'].map(mapping_amt)
df.drop(columns=['이용금액대'], inplace=True)

# %%
# 저장 직전의 컬럼과 0/NaN 컬럼 재확인
zero_cols = [c for c in df.columns if df[c].eq(0).all()]
na_cols   = [c for c in df.columns if df[c].isna().any()]

print("저장 직전 0 전부 컬럼:", zero_cols)
print("저장 직전 NaN 있는 컬럼:", na_cols)
print("저장 직전 전체 컬럼 수:", len(df.columns))
# Out:
# 저장 직전 0 전부 컬럼: []
# 저장 직전 NaN 있는 컬럼: ['_1순위업종', '_2순위업종', '_3순위업종', '_1순위쇼핑업종', '_2순위쇼핑업종', '_3순위쇼핑업종', '_1순위교통업종', '_2순위교통업종', '_3순위교통업종', '_1순위여유업종', '_2순위여유업종', '_3순위여유업종', '_1순위납부업종', '_2순위납부업종', '_3순위납부업종', '최종카드론_금융상환방식코드', '최종카드론_신청경로코드', 'Segment', '최종이용일자_기본_dt', '최종이용일자_신판_dt', '최종이용일자_CA_dt', '최종이용일자_카드론_dt', '최종이용일자_체크_dt', '최종이용일자_일시불_dt', '최종이용일자_할부_dt', '최종카드론_대출일자_dt']
# 저장 직전 전체 컬럼 수: 356

# %%
# Parquet 파일로 저장
df.to_parquet('승인매출정보_전처리.parquet', engine='pyarrow', index=False)

# %%
# 저장된 파일 불러와서 확인하기
df2 = pd.read_parquet('승인매출정보_전처리.parquet')
zero_after = [c for c in df2.columns if df2[c].eq(0).all()]
na_after   = [c for c in df2.columns if df2[c].isna().any()]

print("로드 후 0 전부 컬럼:", zero_after)
print("로드 후 NaN 있는 컬럼:", na_after)
print("로드 후 전체 컬럼 수:", len(df2.columns))
# Out:
# 로드 후 0 전부 컬럼: []
# 로드 후 NaN 있는 컬럼: ['_1순위업종', '_2순위업종', '_3순위업종', '_1순위쇼핑업종', '_2순위쇼핑업종', '_3순위쇼핑업종', '_1순위교통업종', '_2순위교통업종', '_3순위교통업종', '_1순위여유업종', '_2순위여유업종', '_3순위여유업종', '_1순위납부업종', '_2순위납부업종', '_3순위납부업종', '최종카드론_금융상환방식코드', '최종카드론_신청경로코드', 'Segment', '최종이용일자_기본_dt', '최종이용일자_신판_dt', '최종이용일자_CA_dt', '최종이용일자_카드론_dt', '최종이용일자_체크_dt', '최종이용일자_일시불_dt', '최종이용일자_할부_dt', '최종카드론_대출일자_dt']
# 로드 후 전체 컬럼 수: 356
