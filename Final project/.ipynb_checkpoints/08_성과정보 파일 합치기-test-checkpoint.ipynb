# %%
# 기본 라이브러리
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 경고 뜨지 않게
import warnings
warnings.filterwarnings('ignore')

# %%
# 6개 parquet 파일 경로 리스트 
file_list = [
    'open/test/8.성과정보/201807_test_성과정보.parquet',
    'open/test/8.성과정보/201808_test_성과정보.parquet',
    'open/test/8.성과정보/201809_test_성과정보.parquet',
    'open/test/8.성과정보/201810_test_성과정보.parquet',
    'open/test/8.성과정보/201811_test_성과정보.parquet',
    'open/test/8.성과정보/201812_test_성과정보.parquet'
]

# 빈 데이터프레임 리스트 생성
dfs = []

# 각 파일을 읽어서 dfs 리스트에 추가
for file in file_list:
    df = pd.read_parquet(file)
    dfs.append(df)

# 데이터프레임 합치기 (행 기준으로 아래로 붙이기)
merged_df = pd.concat(dfs, ignore_index=True)

# %%
# 합친 데이터 확인
print(merged_df.shape)
print(merged_df.head())
# Out:
# (600000, 49)
#      기준년월          ID  증감율_이용건수_신용_전월  증감율_이용건수_신판_전월  증감율_이용건수_일시불_전월  \
# 0  201807  TEST_00000        0.204652        0.204652         0.204652
# 1  201807  TEST_00001       -0.340448       -0.290936        -0.257185
# 2  201807  TEST_00002       -0.214236       -0.214236        -0.210419
# 3  201807  TEST_00003        0.011708        0.011708         0.011708
# 4  201807  TEST_00004       -0.136222       -0.136222        -0.052585
#
#    증감율_이용건수_할부_전월  증감율_이용건수_CA_전월  증감율_이용건수_체크_전월  증감율_이용건수_카드론_전월  \
# 0        0.000000        0.000000        0.000000              0.0
# 1       -0.583068       -1.999856        0.011254              0.0
# 2       -1.999996        0.000000        0.000000              0.0
# 3        0.000000        0.000000        0.000000              0.0
# 4       -1.999996        0.000000       -0.379615              0.0
#
#    증감율_이용금액_신용_전월  ...  변동률_RV일시불평잔  변동률_할부평잔  변동률_CA평잔  변동률_RVCA평잔  \
# ...

# %%
# 필요하면 하나로 합친 데이터 저장
merged_df.to_parquet('open/test/8.성과정보/2018_test_성과정보.parquet')

# %%
df = pd.read_parquet ('open/test/8.성과정보/2018_test_성과정보.parquet')
df
# Out:
#           기준년월          ID  증감율_이용건수_신용_전월  증감율_이용건수_신판_전월  증감율_이용건수_일시불_전월  \
# 0       201807  TEST_00000        0.204652        0.204652         0.204652
# 1       201807  TEST_00001       -0.340448       -0.290936        -0.257185
# 2       201807  TEST_00002       -0.214236       -0.214236        -0.210419
# 3       201807  TEST_00003        0.011708        0.011708         0.011708
# 4       201807  TEST_00004       -0.136222       -0.136222        -0.052585
# ...        ...         ...             ...             ...              ...
# 599995  201812  TEST_99995        0.000000        0.000000         0.000000
# 599996  201812  TEST_99996        0.000000        0.000000         0.000000
# 599997  201812  TEST_99997        0.000000        0.000000         0.000000
# 599998  201812  TEST_99998       -0.048050       -0.048050        -0.048050
# 599999  201812  TEST_99999        0.000000        0.000000         0.000000
#
# ...
