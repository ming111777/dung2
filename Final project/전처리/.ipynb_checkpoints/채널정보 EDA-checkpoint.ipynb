# %%
# 기본 라이브러리 임포트
import pandas as pd             
import numpy as np             
import matplotlib.pyplot as plt 
import seaborn as sns           
import gc                       # 가비지 컬렉션(메모리 해제)
import re                       # 정규 표현식 처리
from collections import defaultdict  # 기본값이 있는 딕셔너리 생성

# 경고 메시지 억제
import warnings
warnings.filterwarnings('ignore')   

# 그래프 스타일 설정
sns.set()                           # seaborn 기본 스타일 적용

# matplotlib 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # 한글 폰트 설정
# plt.rcParams['font.family'] = 'AppleGothic'  
plt.rcParams['figure.figsize'] = (12, 6)       # 그림 크기 설정 (가로, 세로)
plt.rcParams['font.size'] = 14                 # 폰트 크기 설정
plt.rcParams['axes.unicode_minus'] = False     # 마이너스 기호 깨짐 방지

# 결측치 시각화 라이브러리 임포트
import missingno                          # 결측치 분포를 시각화하는 유틸리티

# 범주형 변수 레이블 인코딩을 위한 도구 임포트
from sklearn.preprocessing import LabelEncoder

# 중복 조합 생성에 사용할 product 함수 임포트
from itertools import product

# 회귀 및 통계 분석을 위한 statsmodels 임포트
import statsmodels.api as sm

# 다중공선성 진단용 VIF 계산 함수 임포트
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# 데이터를 불러온다.
df2 = pd.read_parquet('채널정보_전처리.parquet')
df2
# Out:
#            기준년월            ID  인입일수_ARS_R6M  인입월수_ARS_R6M  인입후경과월_ARS  \
# 0        201807  TRAIN_000000             8             6           0
# 1        201807  TRAIN_000001             0             0           0
# 2        201807  TRAIN_000002             1             1           0
# 3        201807  TRAIN_000003            10             6           0
# 4        201807  TRAIN_000004             0             0           0
# ...         ...           ...           ...           ...         ...
# 2999995  201812    TEST_99995             0             0           0
# 2999996  201812    TEST_99996             0             0           0
# 2999997  201812    TEST_99997             0             0           0
# 2999998  201812    TEST_99998             0             0           0
# 2999999  201812    TEST_99999             0             0           0
#
#          인입횟수_ARS_B0M  이용메뉴건수_ARS_B0M  인입일수_ARS_B0M  방문월수_PC_R6M  \
# 0                   2               6             2            0
# 1                   0               0             0            0
# 2                   2               5             1            6
# 3                   2               6             2            0
# 4                   0               0             0            0
# ...               ...             ...           ...          ...
# 2999995             0               0             0            0
# 2999996             0               0             0            0
# 2999997             0               0             0            0
# 2999998             0               0             0            0
# 2999999             0               0             0            0
#
#          방문후경과월_PC_R6M  ...  홈페이지_금융건수_R6M  홈페이지_선결제건수_R6M  홈페이지_금융건수_R3M  \
# 0                    6  ...              0               0              0
# 1                    6  ...              0               0              0
# 2                    0  ...             11               6              5
# 3                    6  ...              0               0              0
# 4                    6  ...              0               0              0
# ...                ...  ...            ...             ...            ...
# 2999995              6  ...              0               0              0
# 2999996              6  ...              3               7              3
# 2999997              6  ...              0               0              0
# 2999998              6  ...              7              22              4
# 2999999              6  ...              0               0              0
#
#          홈페이지_선결제건수_R3M  Segment  인입횟수_ARS_R6M_num  이용메뉴건수_ARS_R6M_num  \
# 0                     0        D                10                  10
# 1                     0        E                 1                   1
# 2                     5        C                 1                   1
# 3                     0        D                10                  10
# 4                     0        E                 1                   1
# ...                 ...      ...               ...                 ...
# 2999995               0     None                 1                   1
# 2999996               3     None                 1                   1
# 2999997               0     None                 1                   1
# 2999998              12     None                 1                   1
# 2999999               0     None                 1                   1
#
#          방문횟수_PC_R6M_num  방문일수_PC_R6M_num  방문횟수_앱_R6M_num
# 0                      1                1               1
# 1                      1                1               1
# 2                     10               10              30
# 3                      1                1               1
# 4                      1                1               1
# ...                  ...              ...             ...
# 2999995                1                1               1
# 2999996                1                1              10
# 2999997                1                1               1
# 2999998                1                1              40
# 2999999                1                1               1
#
# [3000000 rows x 57 columns]

# %% [markdown]
# ### EDA
# - 대부분의 값이 0에 몰려 있기 때문에, 0과 0이 아닌 값을 구분하여 분석을 진행

# %%
# 분석에서 제외할 컬럼 리스트
exclude_cols = ['ID', 'Segment', '기준년월']

# 0 vs 비0 플래그 대상으로 사용할 수치형 컬럼 리스트
num_cols = [
    col for col in df2.select_dtypes(include='number').columns
    if col not in exclude_cols
]

# 비0 비율 계산 후, 5% 이상 95% 이하인 컬럼만 선별
ratio = {col: (df2[col] != 0).mean() * 100 for col in num_cols}
valid_cols = [col for col, pct in ratio.items() if 5 <= pct <= 95]

# 유효 컬럼 목록 출력
display(pd.DataFrame({'비0 비율(%)': [ratio[c] for c in valid_cols]}, index=valid_cols))

# 유효 컬럼들에 대해 EDA 수행
for orig_col in valid_cols:
    # 비0 플래그 생성
    flag_col = f'{orig_col}_flag'
    df2[flag_col] = (df2[orig_col] != 0).astype(int)
    
    # 비0 비율 계산 및 출력
    pct_nonzero = ratio[orig_col]
    display(pd.DataFrame({'비0 비율(%)': [pct_nonzero]}, index=[orig_col]))
    
    # 비0 그룹 통계 요약 출력
    group_stats = df2[df2[flag_col] == 1][orig_col].agg(
        ['count', 'mean', 'median', 'std', 'min', 'max']
    )
    display(group_stats.to_frame(name=f'{orig_col} 비0 그룹 통계'))
    
    # 세그먼트별 비0 비율 교차표 출력
    cross_tab = pd.crosstab(df2['Segment'], df2[flag_col], normalize='index') * 100
    display(cross_tab[1].to_frame(name=f'{orig_col} 비0 비율(%)'))
    
    # 비0 값 히스토그램 시각화
    non_zero_values = df2.loc[df2[flag_col] == 1, orig_col]
    plt.figure(figsize=(6,3))
    plt.hist(non_zero_values, bins=30)
    plt.title(f'{orig_col} 비0 히스토그램')
    plt.xlabel(orig_col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()
# Out:
#                     비0 비율(%)
# 인입일수_ARS_R6M       29.864600
# 인입월수_ARS_R6M       29.337567
# 인입후경과월_ARS         21.668533
# 인입횟수_ARS_B0M        6.196033
# 이용메뉴건수_ARS_B0M      6.231800
# 인입일수_ARS_B0M        6.194633
# 방문월수_PC_R6M        13.962667
# 방문후경과월_PC_R6M      92.414600
# 방문일수_앱_R6M         22.879767
# 방문월수_앱_R6M         23.326433
# 방문후경과월_앱_R6M       81.586267
# 방문횟수_PC_B0M         7.039500
# 방문일수_PC_B0M         7.028533
# 방문횟수_앱_B0M         17.878133
# 방문일수_앱_B0M         17.864333
# 인입횟수_IB_R6M        28.503167
# 인입일수_IB_R6M        28.380967
# 인입월수_IB_R6M        28.303300
# 이용메뉴건수_IB_R6M      28.239533
# 상담건수_R6M           29.738067
# IB문의건수_사용승인내역_R6M   5.240167
# IB문의건수_선결제_R6M      5.698900
# 불만제기후경과월_R12M      54.718600
# 당사멤버쉽_방문횟수_B0M      5.086600
# 당사멤버쉽_방문횟수_R6M     13.649233
# 당사멤버쉽_방문월수_R6M     14.476767
# 홈페이지_금융건수_R6M      12.514500
# 홈페이지_선결제건수_R6M     12.323100
# 홈페이지_금융건수_R3M      11.074833
# 홈페이지_선결제건수_R3M     10.599300
#               비0 비율(%)
# 인입일수_ARS_R6M   29.8646
#         인입일수_ARS_R6M 비0 그룹 통계
# count           895938.000000
# mean                 2.917283
# median               2.000000
# std                  2.604524
# min                  1.000000
# max                 12.000000
#          인입일수_ARS_R6M 비0 비율(%)
# Segment
# A                    51.337449
# B                    50.000000
# C                    46.287327
# D                    40.691555
# E                    26.757601
#                비0 비율(%)
# 인입월수_ARS_R6M  29.337567
#         인입월수_ARS_R6M 비0 그룹 통계
# count           880127.000000
# mean                 1.873797
# median               1.000000
# std                  1.540324
# min                  1.000000
# max                  6.000000
#          인입월수_ARS_R6M 비0 비율(%)
# Segment
# A                    50.514403
# B                    52.083333
# C                    45.526295
# D                    40.033845
# E                    26.274887
#              비0 비율(%)
# 인입후경과월_ARS  21.668533
#         인입후경과월_ARS 비0 그룹 통계
# count         650056.000000
# mean               3.240953
# median             3.000000
# std                1.390331
# min                1.000000
# max                5.000000
#          인입후경과월_ARS 비0 비율(%)
# Segment
# A                  34.567901
# B                  25.000000
# C                  30.395799
# D                  27.777301
# E                  19.960230
#               비0 비율(%)
# 인입횟수_ARS_B0M  6.196033
#         인입횟수_ARS_B0M 비0 그룹 통계
# count           185881.000000
# mean                 2.068011
# median               2.000000
# std                  0.251809
# min                  1.000000
# max                  3.000000
#          인입횟수_ARS_B0M 비0 비율(%)
# Segment
# A                    13.374486
# B                    22.916667
# C                    13.223607
# D                    10.585210
# E                     4.903301
#                 비0 비율(%)
# 이용메뉴건수_ARS_B0M    6.2318
#         이용메뉴건수_ARS_B0M 비0 그룹 통계
# count             186954.000000
# mean                   5.144640
# median                 5.000000
# std                    0.416543
# min                    4.000000
# max                    7.000000
#          이용메뉴건수_ARS_B0M 비0 비율(%)
# Segment
# A                      13.888889
# B                      22.916667
# C                      13.297280
# D                      10.661089
# E                       4.930460
#               비0 비율(%)
# 인입일수_ARS_B0M  6.194633
#         인입일수_ARS_B0M 비0 그룹 통계
# count           185839.000000
# mean                 1.692417
# median               2.000000
# std                  0.461494
# min                  1.000000
# max                  2.000000
#          인입일수_ARS_B0M 비0 비율(%)
# Segment
# A                    13.580247
# B                    22.916667
# C                    13.217337
# D                    10.591223
# E                     4.900232
#               비0 비율(%)
# 방문월수_PC_R6M  13.962667
#         방문월수_PC_R6M 비0 그룹 통계
# count          418880.000000
# mean                3.411569
# median              1.000000
# std                 2.498036
# min                 1.000000
# max                 6.000000
#          방문월수_PC_R6M 비0 비율(%)
# Segment
# A                   47.016461
# B                   50.694444
# C                   31.689788
# D                   24.417453
# E                   10.864951
#                비0 비율(%)
# 방문후경과월_PC_R6M   92.4146
#         방문후경과월_PC_R6M 비0 그룹 통계
# count             2.772438e+06
# mean              5.840581e+00
# median            6.000000e+00
# std               7.241254e-01
# min               1.000000e+00
# max               6.000000e+00
#          방문후경과월_PC_R6M 비0 비율(%)
# Segment
# A                     72.325103
# B                     65.972222
# C                     80.772004
# D                     86.218725
# E                     94.314098
#              비0 비율(%)
# 방문일수_앱_R6M  22.879767
#         방문일수_앱_R6M 비0 그룹 통계
# count         686393.000000
# mean              16.918694
# median            11.000000
# std               14.800214
# min                1.000000
# max               64.000000
#          방문일수_앱_R6M 비0 비율(%)
# Segment
# A                  32.818930
# B                  65.277778
# C                  38.732659
# D                  36.586092
# E                  19.331371
#              비0 비율(%)
# 방문월수_앱_R6M  23.326433
#         방문월수_앱_R6M 비0 그룹 통계
# count         699793.000000
# mean               4.492977
# median             6.000000
# std                2.049527
# min                1.000000
# max                6.000000
#          방문월수_앱_R6M 비0 비율(%)
# Segment
# A                  33.230453
# B                  65.972222
# C                  39.171565
# D                  37.084600
# E                  19.764450
#                비0 비율(%)
# 방문후경과월_앱_R6M  81.586267
#         방문후경과월_앱_R6M 비0 그룹 통계
# count            2.447588e+06
# mean             5.849912e+00
# median           6.000000e+00
# std              7.438046e-01
# min              1.000000e+00
# max              6.000000e+00
#          방문후경과월_앱_R6M 비0 비율(%)
# Segment
# A                    74.279835
# B                    40.277778
# C                    68.419939
# D                    69.809473
# E                    84.599792
#              비0 비율(%)
# 방문횟수_PC_B0M    7.0395
#         방문횟수_PC_B0M 비0 그룹 통계
# count          211185.000000
# mean                5.733362
# median              6.000000
# std                 0.596023
# min                 3.000000
# max                 9.000000
#          방문횟수_PC_B0M 비0 비율(%)
# Segment
# A                   25.411523
# B                   31.944444
# C                   18.109570
# D                   12.863000
# E                    5.247048
#              비0 비율(%)
# 방문일수_PC_B0M  7.028533
#         방문일수_PC_B0M 비0 그룹 통계
# count          210856.000000
# mean                4.255288
# median              4.000000
# std                 0.483731
# min                 2.000000
# max                 6.000000
#          방문일수_PC_B0M 비0 비율(%)
# Segment
# A                   25.000000
# B                   31.944444
# C                   18.070382
# D                   12.840666
# E                    5.241221
#              비0 비율(%)
# 방문횟수_앱_B0M  17.878133
#         방문횟수_앱_B0M 비0 그룹 통계
# count         536344.000000
# mean               5.341708
# median             4.000000
# std                2.491530
# min                1.000000
# max               16.000000
#          방문횟수_앱_B0M 비0 비율(%)
# Segment
# A                  24.897119
# B                  56.944444
# C                  30.681872
# D                  29.399099
# E                  14.939294
#              비0 비율(%)
# 방문일수_앱_B0M  17.864333
#         방문일수_앱_B0M 비0 그룹 통계
# count         535930.000000
# mean               4.301101
# median             4.000000
# std                1.856895
# min                1.000000
# max               11.000000
#          방문일수_앱_B0M 비0 비율(%)
# Segment
# A                  25.102881
# B                  56.944444
# C                  30.659143
# D                  29.385641
# E                  14.925559
#               비0 비율(%)
# 인입횟수_IB_R6M  28.503167
#         인입횟수_IB_R6M 비0 그룹 통계
# count          855095.000000
# mean                3.481573
# median              3.000000
# std                 2.503959
# min                 1.000000
# max                15.000000
#          인입횟수_IB_R6M 비0 비율(%)
# Segment
# A                   52.777778
# B                   52.777778
# C                   44.093581
# D                   38.768819
# E                   25.567727
#               비0 비율(%)
# 인입일수_IB_R6M  28.380967
#         인입일수_IB_R6M 비0 그룹 통계
# count          851429.000000
# mean                2.227109
# median              2.000000
# std                 1.498784
# min                 1.000000
# max                 8.000000
#          인입일수_IB_R6M 비0 비율(%)
# Segment
# A                   51.954733
# B                   52.083333
# C                   43.882749
# D                   38.611908
# E                   25.457584
#              비0 비율(%)
# 인입월수_IB_R6M   28.3033
#         인입월수_IB_R6M 비0 그룹 통계
# count          849099.000000
# mean                1.486571
# median              1.000000
# std                 0.790252
# min                 1.000000
# max                 6.000000
#          인입월수_IB_R6M 비0 비율(%)
# Segment
# A                   52.983539
# B                   52.777778
# C                   43.807508
# D                   38.484489
# E                   25.392133
#                 비0 비율(%)
# 이용메뉴건수_IB_R6M  28.239533
#         이용메뉴건수_IB_R6M 비0 그룹 통계
# count            847186.000000
# mean                  2.190785
# median                2.000000
# std                   1.163787
# min                   1.000000
# max                   6.000000
#          이용메뉴건수_IB_R6M 비0 비율(%)
# Segment
# A                     51.851852
# B                     52.083333
# C                     43.668783
# D                     38.452992
# E                     25.323404
#            비0 비율(%)
# 상담건수_R6M  29.738067
#         상담건수_R6M 비0 그룹 통계
# count       892142.000000
# mean             3.540074
# median           3.000000
# std              2.481364
# min              1.000000
# max             13.000000
#          상담건수_R6M 비0 비율(%)
# Segment
# A                55.761317
# B                55.555556
# C                46.038875
# D                40.339650
# E                26.690485
#                    비0 비율(%)
# IB문의건수_사용승인내역_R6M  5.240167
#         IB문의건수_사용승인내역_R6M 비0 그룹 통계
# count                157205.000000
# mean                      1.893076
# median                    2.000000
# std                       0.309018
# min                       1.000000
# max                       2.000000
#          IB문의건수_사용승인내역_R6M 비0 비율(%)
# Segment
# A                         16.358025
# B                         18.055556
# C                         11.601223
# D                          8.984315
# E                          4.126787
#                 비0 비율(%)
# IB문의건수_선결제_R6M    5.6989
#         IB문의건수_선결제_R6M 비0 그룹 통계
# count             170967.000000
# mean                   2.869267
# median                 3.000000
# std                    0.945718
# min                    1.000000
# max                    6.000000
#          IB문의건수_선결제_R6M 비0 비율(%)
# Segment
# A                       9.465021
# B                      16.666667
# C                      11.228153
# D                       9.695283
# E                       4.571729
#                비0 비율(%)
# 불만제기후경과월_R12M   54.7186
#         불만제기후경과월_R12M 비0 그룹 통계
# count                1641558.0
# mean                      12.0
# median                    12.0
# std                        0.0
# min                       12.0
# max                       12.0
#          불만제기후경과월_R12M 비0 비율(%)
# Segment
# A                     84.567901
# B                     83.333333
# C                     76.980955
# D                     70.759531
# E                     50.344007
#                 비0 비율(%)
# 당사멤버쉽_방문횟수_B0M    5.0866
#         당사멤버쉽_방문횟수_B0M 비0 그룹 통계
# count             152598.000000
# mean                  27.478814
# median                23.000000
# std                   11.495011
# min                    1.000000
# max                   63.000000
#          당사멤버쉽_방문횟수_B0M 비0 비율(%)
# Segment
# A                       5.041152
# B                       8.333333
# C                      11.844972
# D                       8.993477
# E                       3.924139
#                  비0 비율(%)
# 당사멤버쉽_방문횟수_R6M  13.649233
#         당사멤버쉽_방문횟수_R6M 비0 그룹 통계
# count             409477.000000
# mean                  83.627005
# median                 8.000000
# std                   96.668676
# min                    1.000000
# max                  259.000000
#          당사멤버쉽_방문횟수_R6M 비0 비율(%)
# Segment
# A                      17.181070
# B                      22.916667
# C                      26.355514
# D                      22.668522
# E                      11.174151
#                  비0 비율(%)
# 당사멤버쉽_방문월수_R6M  14.476767
#         당사멤버쉽_방문월수_R6M 비0 그룹 통계
# count             434303.000000
# mean                   4.066486
# median                 6.000000
# std                    2.378948
# min                    1.000000
# max                    6.000000
#          당사멤버쉽_방문월수_R6M 비0 비율(%)
# Segment
# A                      18.209877
# B                      25.694444
# C                      28.108002
# D                      24.174068
# E                      11.819763
#                비0 비율(%)
# 홈페이지_금융건수_R6M   12.5145
#         홈페이지_금융건수_R6M 비0 그룹 통계
# count            375435.000000
# mean                  5.878008
# median                6.000000
# std                   2.323408
# min                   1.000000
# max                  16.000000
#          홈페이지_금융건수_R6M 비0 비율(%)
# Segment
# A                     24.897119
# B                     59.722222
# C                     24.682969
# D                     21.550673
# E                     10.081933
#                 비0 비율(%)
# 홈페이지_선결제건수_R6M   12.3231
#         홈페이지_선결제건수_R6M 비0 그룹 통계
# count             369693.000000
# mean                   7.902711
# median                 7.000000
# std                    4.957356
# min                    1.000000
# max                   30.000000
#          홈페이지_선결제건수_R6M 비0 비율(%)
# Segment
# A                      24.485597
# B                      45.138889
# C                      24.415707
# D                      21.437571
# E                       9.879389
#                 비0 비율(%)
# 홈페이지_금융건수_R3M  11.074833
#         홈페이지_금융건수_R3M 비0 그룹 통계
# count            332245.000000
# mean                  3.660895
# median                3.000000
# std                   0.879700
# min                   2.000000
# max                   8.000000
#          홈페이지_금융건수_R3M 비0 비율(%)
# Segment
# A                     23.456790
# B                     52.083333
# C                     22.352849
# D                     19.370522
# E                      8.849657
#                 비0 비율(%)
# 홈페이지_선결제건수_R3M   10.5993
#         홈페이지_선결제건수_R3M 비0 그룹 통계
# count             317979.000000
# mean                   4.955381
# median                 4.000000
# std                    2.294961
# min                    1.000000
# max                   16.000000
#          홈페이지_선결제건수_R3M 비0 비율(%)
# Segment
# A                      21.502058
# B                      41.666667
# C                      21.469551
# D                      18.825628
# E                       8.397223
